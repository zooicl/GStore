# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import lightgbm as lgb
import pandas as pd
import numpy as np
import datetime
from sklearn.preprocessing import LabelEncoder
from multiprocessing import Pool
import subprocess
import matplotlib.pyplot as plt
import os
import time
from sklearn.model_selection import TimeSeriesSplit, KFold, StratifiedKFold
from sklearn.model_selection import GroupKFold
from features import get_features
from report import report
from report import get_feature_importance
import operator
# Out:
# /Users/hyundai/anaconda3/lib/python3.6/site-packages/lightgbm/__init__.py:45: FutureWarning: Starting from version 2.2.1, the library file in distribution wheels for macOS will be built by the Apple Clang compiler.
# This means that in case of installing LightGBM from PyPI via the ``pip install lightgbm`` command, you won't need to install the gcc compiler anymore.
# Instead of that, you'll need to install the OpenMP library, which is required for running LightGBM on the system with the Apple Clang compiler.
# You can install the OpenMP library by the following command: ``brew install libomp``.
#   "You can install the OpenMP library by the following command: ``brew install libomp``.", FutureWarning)

# %% [markdown]
# ### Load Data

# %%
df_train = pd.read_csv("input/parsed_train.csv", dtype={'fullVisitorId': 'str'})
df_test = pd.read_csv("input/parsed_test.csv", dtype={'fullVisitorId': 'str'})
# Out:
# /Users/hyundai/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (49) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ### Feature Engineering

# %%
df_train = get_features(df_train)
df_test = get_features(df_test)
# Out:
# 'fea_date_time'  21227.36 ms
# 'fea_format'  1887.81 ms
# 'fea_device'  2647.82 ms
# 'fea_totals'  2931.98 ms
# 'fea_geo_network'  1363.06 ms
# 'fea_traffic_source'  3061.27 ms
# {'hour_unique_user_count', 'source_country', 'count_hits_per_network_domain', 'mean_hits_per_hour', 'var_hits_per_hour', 'sum_hits_per_day', 'month_unique_s_count', 'hour', 'sum_pageviews_per_network_domain', 'mean_hits_per_network_domain', 'campaign_medium', 'medium_hits_max', 'sum_hits_per_hour', 'mean_hits_per_day', 'sum_hits_per_network_domain', 'weekday_unique_user_count', 'user_hour_min', 'weekofmonth', 'weekofyear', 'user_hour_max', 'day_unique_s_count', 'max_hits_per_day', 'max_hits_per_hour', 'month_unique_user_count', 'mean_pageviews_per_network_domain', 'medium_hits_mean', 'medium_hits_min', 'month', 'weekday', 'var_hits_per_day', 'user_hour_mean', 'min_hits_per_day', 'weekday_unique_s_count', 'totals_pageviews_hit_rate', 'browser_category', 'count_pageviews_per_network_domain', 'medium_hits_sum', 'day_unique_user_count', 'mean_hour_per_browser_operatingSystem', 'min_hits_per_hour', 'day', 'hour_unique_s_count', 'browser_operatingSystem'}
# 'fea_date_time'  18366.35 ms
# 'fea_format'  1620.31 ms
# 'fea_device'  2331.96 ms
# 'fea_totals'  2507.15 ms
# 'fea_geo_network'  1245.15 ms
# 'fea_traffic_source'  2679.57 ms
# {'hour_unique_user_count', 'source_country', 'count_hits_per_network_domain', 'mean_hits_per_hour', 'var_hits_per_hour', 'sum_hits_per_day', 'month_unique_s_count', 'hour', 'sum_pageviews_per_network_domain', 'mean_hits_per_network_domain', 'campaign_medium', 'medium_hits_max', 'sum_hits_per_hour', 'mean_hits_per_day', 'sum_hits_per_network_domain', 'weekday_unique_user_count', 'user_hour_min', 'weekofmonth', 'weekofyear', 'user_hour_max', 'day_unique_s_count', 'max_hits_per_day', 'max_hits_per_hour', 'month_unique_user_count', 'mean_pageviews_per_network_domain', 'medium_hits_mean', 'medium_hits_min', 'month', 'weekday', 'var_hits_per_day', 'user_hour_mean', 'min_hits_per_day', 'weekday_unique_s_count', 'totals_pageviews_hit_rate', 'browser_category', 'count_pageviews_per_network_domain', 'medium_hits_sum', 'day_unique_user_count', 'mean_hour_per_browser_operatingSystem', 'min_hits_per_hour', 'day', 'hour_unique_s_count', 'browser_operatingSystem'}

# %%
# df_test['totals_transactionRevenue'] = 0

# train_size = df_train.shape[0]
# df_merge = pd.concat([df_train, df_test])
# df_merge = get_features(df_merge)
                      
# df_train = df_merge[:train_size]
# df_test = df_merge[train_size:]
# df_test.drop('totals_transactionRevenue', axis=1, inplace=True)

# %% [markdown]
# ### Split X and y, Remove not_used_cols

# %%
target_col = 'totals_transactionRevenue'
df_train_y = df_train[target_col].astype(float)
df_train_y.fillna(0, inplace=True)
df_train_y = np.log1p(df_train_y)

# %%
not_used_cols = [
#     "visitNumber", 
    "date", "fullVisitorId", "sessionId", "visitId",
    "visitStartTime", 'trafficSource_referralPath',
    'trafficSource_campaignCode', target_col,
    'trafficSource_adwordsClickInfo.gclId',
    'trafficSource_adContent',
    'trafficSource_adwordsClickInfo.slot',
    'trafficSource_adwordsClickInfo.gclId',
    'trafficSource_adwordsClickInfo.adNetworkType',
    
    'trafficSource_campaign',
    'socialEngagementType',
    'device_browserSize',
    'device_browserVersion',
    'device_flashVersion',
    'device_language',
    'device_mobileDeviceBranding',
    'device_mobileDeviceInfo',
    'device_mobileDeviceMarketingName',
    'device_mobileDeviceModel',
    'device_mobileInputSelector',
    'device_operatingSystemVersion',
    'device_screenColors',
    'device_screenResolution',
    'geoNetwork_cityId',
    'geoNetwork_latitude',
    'geoNetwork_longitude',
    'geoNetwork_networkLocation',
    'totals_visits',
    'trafficSource_adwordsClickInfo.criteriaParameters',
    'trafficSource_adwordsClickInfo.isVideoAd',
    'trafficSource_adwordsClickInfo.page',
]

df_train_idx = df_train[['fullVisitorId', target_col]]
df_train_X = df_train.drop(not_used_cols, axis=1)

df_test_idx = df_test[['fullVisitorId']]
del_cols = list(set(df_test.columns) & set(not_used_cols))
df_test_X = df_test.drop(del_cols, axis=1)

# %% [markdown]
# ### Label Encoding

# %%
categorical_feature = list(df_train_X.select_dtypes(exclude=np.number).columns)
print(categorical_feature)

df_train_X[categorical_feature].fillna('NA_NULL', inplace=True)
df_train_X.fillna(0, inplace=True)

df_test_X[categorical_feature].fillna('NA_NULL', inplace=True)
df_test_X.fillna(0, inplace=True)

df_merge = pd.concat([df_train_X[categorical_feature], df_test_X[categorical_feature]])
train_size = df_train_X.shape[0]
for c in categorical_feature:
    st = time.time()
    
    labels, _ = pd.factorize(df_merge[c].values.astype('str'))
    
    df_train_X[c] = labels[:train_size]
    df_test_X[c] = labels[train_size:]
    print(c, time.time() - st)
# Out:
# ['channelGrouping', 'device_browser', 'device_deviceCategory', 'device_isMobile', 'device_operatingSystem', 'geoNetwork_city', 'geoNetwork_continent', 'geoNetwork_country', 'geoNetwork_metro', 'geoNetwork_networkDomain', 'geoNetwork_region', 'geoNetwork_subContinent', 'trafficSource_isTrueDirect', 'trafficSource_keyword', 'trafficSource_medium', 'trafficSource_source', 'browser_category', 'browser_operatingSystem', 'source_country', 'campaign_medium']
# /Users/hyundai/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:3787: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   downcast=downcast, **kwargs)
# channelGrouping 1.0430803298950195
# device_browser 1.2723309993743896
# device_deviceCategory 0.9302587509155273
# device_isMobile 0.9015848636627197
# device_operatingSystem 0.9350080490112305
# geoNetwork_city 1.2669692039489746
# geoNetwork_continent 0.9648580551147461
# geoNetwork_country 1.0812816619873047
# geoNetwork_metro 1.18623685836792
# geoNetwork_networkDomain 1.176877737045288
# geoNetwork_region 1.0024158954620361
# geoNetwork_subContinent 0.849539041519165
# trafficSource_isTrueDirect 0.9462931156158447
# trafficSource_keyword 2.077270984649658
# trafficSource_medium 0.6414670944213867
# trafficSource_source 0.9077229499816895
# browser_category 0.9566898345947266
# browser_operatingSystem 0.9681520462036133
# source_country 1.0780439376831055
# campaign_medium 0.9078779220581055

# %% [markdown]
# ### Training with CV and TS

# %%
N_SPLITS = 5
feature_name = list(df_train_X.columns)

fold_cols = []
prediction_train = np.zeros(df_train_X.shape[0])
prediction = np.zeros(df_test_X.shape[0])

# %%
def modeling(fold_col, X_train, X_valid, y_train, y_valid):
    train = lgb.Dataset(
        X_train.values,
        label=y_train.values,
        feature_name=feature_name,
        categorical_feature=categorical_feature)

    valid = lgb.Dataset(
        X_valid.values,
        label=y_valid.values,
        feature_name=feature_name,
        categorical_feature=categorical_feature)

    params = {
        "objective": "regression",
        "metric": "rmse",
        "max_depth": 8,
        "min_child_samples": 20,
        "reg_alpha": 1,
        "reg_lambda": 1,
        "num_leaves": 257,
        "learning_rate": 0.01,
        "subsample": 0.8,
        "colsample_bytree": 0.8,
        "subsample_freq ": 5,
    }
    #     params = {
    #     "objective": "regression",
    #     "metric": "rmse",
    #     "num_leaves": 30,
    #     "min_child_samples": 100,
    #     "learning_rate": 0.1,
    #     "bagging_fraction": 0.7,
    #     "feature_fraction": 0.5,
    #     "bagging_frequency": 5,
    #     "bagging_seed": 2018,
    #     "verbosity": -1
    # }

    # param = {
    #     "objective": "regression",
    #     "metric": "rmse",
    #     "max_depth": 8,
    #     "min_child_samples": 21,
    #     "reg_alpha": 1,
    #     "reg_lambda": 1,
    #     "num_leaves": 257,
    #     "learning_rate": 0.01,
    #     "subsample": 0.82,
    #     "colsample_bytree": 0.84,
    #     "verbosity": -1
    # }
    evals_result = {}
    train_params = {
        'params': params,
        'train_set': train,
        'valid_sets': [train, valid],
        'valid_names': ['train', 'valid'],
        'early_stopping_rounds': 100,  #50
        'num_boost_round': 500,  #500
        'verbose_eval': 25,
        'feval': None,
        'evals_result': evals_result,
        #     'categorical_feature': 'auto',
    }

    model = lgb.train(**train_params)

    global prediction_train, prediction
    print('predict train set')
    pred_train = model.predict(df_train_X, num_iteration=model.best_iteration)
    prediction_train += pred_train
    df_fold_train = df_train_idx.copy()
    df_fold_train[fold_col] = pred_train

    print('predict test set')
    pred = model.predict(df_test_X, num_iteration=model.best_iteration)
    prediction += pred
    df_fold_test = df_test_idx.copy()
    df_fold_test[fold_col] = pred

    # report
    msg = [fold_col, str(df_train_X.columns), str(train_params)]
    submit_file_path = report(df_fold_train, df_fold_test, pred_train, pred, msg, model)
    print(submit_file_path)

    return model

# %% [markdown]
# ### KFold

# %%
folds = KFold(n_splits=N_SPLITS, shuffle=True, random_state=42)

for fold_n, (train_index, test_index) in enumerate(folds.split(df_train_X)):
    fold_col = 'KFold_{0:02d}'.format(fold_n)
    fold_cols.append(fold_col)
    print('Fold:', fold_col)

    X_train, X_valid = df_train_X.iloc[train_index], df_train_X.iloc[test_index]
    y_train, y_valid = df_train_y.iloc[train_index], df_train_y.iloc[test_index]
    
    model = modeling(fold_col, X_train, X_valid, y_train, y_valid)
# Out:
# Fold: KFold_00
# /Users/hyundai/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py:1158: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# /Users/hyundai/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py:725: UserWarning: categorical_feature in param dict is overridden.
#   warnings.warn('categorical_feature in param dict is overridden.')
# Training until validation scores don't improve for 100 rounds.
# [25]	train's rmse: 1.86511	valid's rmse: 1.86287
# [50]	train's rmse: 1.76682	valid's rmse: 1.77749
# [75]	train's rmse: 1.69477	valid's rmse: 1.71916
# [100]	train's rmse: 1.64406	valid's rmse: 1.68107
# [125]	train's rmse: 1.60681	valid's rmse: 1.65605
# [150]	train's rmse: 1.57708	valid's rmse: 1.63933
# [175]	train's rmse: 1.55371	valid's rmse: 1.62817
# [200]	train's rmse: 1.53477	valid's rmse: 1.62089
# [225]	train's rmse: 1.51931	valid's rmse: 1.61599
# [250]	train's rmse: 1.50548	valid's rmse: 1.61244
# [275]	train's rmse: 1.49341	valid's rmse: 1.60972
# [300]	train's rmse: 1.48353	valid's rmse: 1.60818
# [325]	train's rmse: 1.47535	valid's rmse: 1.60689
# [350]	train's rmse: 1.46737	valid's rmse: 1.60629
# [375]	train's rmse: 1.46134	valid's rmse: 1.60577
# [400]	train's rmse: 1.45625	valid's rmse: 1.60558
# [425]	train's rmse: 1.45254	valid's rmse: 1.6056
# [450]	train's rmse: 1.44918	valid's rmse: 1.60581
# [475]	train's rmse: 1.44627	valid's rmse: 1.60591
# [500]	train's rmse: 1.44418	valid's rmse: 1.60604
# Did not meet early stopping. Best iteration is:
# [500]	train's rmse: 1.44418	valid's rmse: 1.60604
# predict train set
# predict test set
# <feature_importance>
# 0 ('totals_pageviews_hit_rate', 8018)
# 1 ('totals_pageviews', 6714)
# 2 ('totals_hits', 4493)
# 3 ('visitNumber', 4190)
# 4 ('weekofyear', 4188)
# 5 ('geoNetwork_city', 3804)
# 6 ('geoNetwork_networkDomain', 3193)
# 7 ('source_country', 2800)
# 8 ('user_hour_mean', 2412)
# 9 ('user_hour_max', 1741)
# 10 ('user_hour_min', 1619)
# 11 ('browser_operatingSystem', 1608)
# 12 ('mean_hits_per_day', 1599)
# 13 ('hour_unique_user_count', 1584)
# 14 ('month', 1510)
# 15 ('day', 1489)
# 16 ('month_unique_user_count', 1472)
# 17 ('var_hits_per_day', 1368)
# 18 ('day_unique_user_count', 1293)
# 19 ('max_hits_per_day', 1269)
# 20 ('mean_hour_per_browser_operatingSystem', 1203)
# 21 ('max_hits_per_hour', 1146)
# 22 ('mean_pageviews_per_network_domain', 1128)
# 23 ('sum_hits_per_hour', 1093)
# 24 ('hour', 1086)
# 25 ('mean_hits_per_hour', 1062)
# 26 ('sum_pageviews_per_network_domain', 1021)
# 27 ('sum_hits_per_day', 923)
# 28 ('day_unique_s_count', 893)
# 29 ('trafficSource_isTrueDirect', 855)
# 30 ('weekday', 836)
# 31 ('geoNetwork_metro', 833)
# 32 ('var_hits_per_hour', 804)
# 33 ('weekday_unique_user_count', 773)
# 34 ('mean_hits_per_network_domain', 615)
# 35 ('medium_hits_mean', 602)
# 36 ('geoNetwork_region', 597)
# 37 ('geoNetwork_country', 588)
# 38 ('trafficSource_source', 577)
# 39 ('month_unique_s_count', 493)
# 40 ('totals_newVisits', 481)
# 41 ('count_pageviews_per_network_domain', 451)
# 42 ('hour_unique_s_count', 427)
# 43 ('device_operatingSystem', 315)
# 44 ('browser_category', 284)
# 45 ('medium_hits_sum', 282)
# 46 ('device_deviceCategory', 213)
# 47 ('totals_bounces', 181)
# 48 ('sum_hits_per_network_domain', 163)
# 49 ('geoNetwork_subContinent', 150)
# 50 ('device_isMobile', 129)
# 51 ('weekday_unique_s_count', 123)
# 52 ('channelGrouping', 98)
# 53 ('weekofmonth', 96)
# 54 ('trafficSource_keyword', 71)
# 55 ('campaign_medium', 58)
# 56 ('count_hits_per_network_domain', 50)
# 57 ('medium_hits_max', 22)
# 58 ('device_browser', 20)
# 59 ('geoNetwork_continent', 17)
# 60 ('trafficSource_medium', 9)
# 61 ('min_hits_per_day', 0)
# 62 ('min_hits_per_hour', 0)
# 63 ('medium_hits_min', 0)
# raw_train: results/2018-09-26T223928__T1.444_V1.606_K/reg_train_2018-09-26T223928.csv
# raw_test: results/2018-09-26T223928__T1.444_V1.606_K/reg_test_2018-09-26T223928.csv
# submit: results/2018-09-26T223928__T1.444_V1.606_K/aiden_2018-09-26T223928.csv.tar.gz
# cp -f reg_lgbm.ipynb results/2018-09-26T223928__T1.444_V1.606_K/reg_lgbm.ipynb
#
# results/2018-09-26T223928__T1.444_V1.606_K/aiden_2018-09-26T223928.csv.tar.gz
# Fold: KFold_01
# Training until validation scores don't improve for 100 rounds.
# [25]	train's rmse: 1.8624	valid's rmse: 1.87597
# [50]	train's rmse: 1.76511	valid's rmse: 1.78567
# [75]	train's rmse: 1.69454	valid's rmse: 1.72425
# [100]	train's rmse: 1.64462	valid's rmse: 1.68312
# [125]	train's rmse: 1.60783	valid's rmse: 1.65566
# [150]	train's rmse: 1.57845	valid's rmse: 1.63653
# [175]	train's rmse: 1.55542	valid's rmse: 1.62332
# [200]	train's rmse: 1.53682	valid's rmse: 1.61413
# [225]	train's rmse: 1.52118	valid's rmse: 1.60754
# [250]	train's rmse: 1.50759	valid's rmse: 1.60311
# [275]	train's rmse: 1.49586	valid's rmse: 1.59994
# [300]	train's rmse: 1.48671	valid's rmse: 1.59785
# [325]	train's rmse: 1.47841	valid's rmse: 1.59638
# [350]	train's rmse: 1.47098	valid's rmse: 1.59519
# [375]	train's rmse: 1.46431	valid's rmse: 1.59452
# [400]	train's rmse: 1.4592	valid's rmse: 1.59405
# [425]	train's rmse: 1.45483	valid's rmse: 1.59374
# [450]	train's rmse: 1.45124	valid's rmse: 1.59361
# [475]	train's rmse: 1.44775	valid's rmse: 1.59338
# [500]	train's rmse: 1.4456	valid's rmse: 1.59324
# Did not meet early stopping. Best iteration is:
# [500]	train's rmse: 1.4456	valid's rmse: 1.59324
# predict train set
# predict test set
# <feature_importance>
# 0 ('totals_pageviews_hit_rate', 8078)
# 1 ('totals_pageviews', 6964)
# 2 ('totals_hits', 4455)
# 3 ('visitNumber', 4449)
# 4 ('weekofyear', 4221)
# 5 ('geoNetwork_city', 4061)
# 6 ('geoNetwork_networkDomain', 3180)
# 7 ('source_country', 2772)
# 8 ('user_hour_mean', 2289)
# 9 ('user_hour_max', 1865)
# 10 ('user_hour_min', 1693)
# 11 ('browser_operatingSystem', 1642)
# 12 ('hour_unique_user_count', 1575)
# 13 ('month_unique_user_count', 1559)
# 14 ('mean_hits_per_day', 1554)
# 15 ('day', 1443)
# 16 ('month', 1437)
# 17 ('max_hits_per_day', 1377)
# 18 ('day_unique_user_count', 1369)
# 19 ('max_hits_per_hour', 1344)
# 20 ('var_hits_per_day', 1330)
# 21 ('mean_hour_per_browser_operatingSystem', 1223)
# 22 ('sum_pageviews_per_network_domain', 1115)
# 23 ('mean_pageviews_per_network_domain', 1084)
# 24 ('hour', 1032)
# 25 ('sum_hits_per_hour', 1025)
# 26 ('mean_hits_per_hour', 1019)
# 27 ('trafficSource_isTrueDirect', 963)
# 28 ('day_unique_s_count', 930)
# 29 ('sum_hits_per_day', 871)
# 30 ('var_hits_per_hour', 842)
# 31 ('weekday', 814)
# 32 ('geoNetwork_metro', 771)
# 33 ('weekday_unique_user_count', 759)
# 34 ('medium_hits_mean', 682)
# 35 ('geoNetwork_country', 622)
# 36 ('geoNetwork_region', 622)
# 37 ('mean_hits_per_network_domain', 527)
# 38 ('trafficSource_source', 510)
# 39 ('totals_newVisits', 496)
# 40 ('month_unique_s_count', 481)
# 41 ('count_pageviews_per_network_domain', 455)
# 42 ('hour_unique_s_count', 444)
# 43 ('medium_hits_sum', 301)
# 44 ('device_operatingSystem', 289)
# 45 ('device_deviceCategory', 272)
# 46 ('browser_category', 241)
# 47 ('sum_hits_per_network_domain', 163)
# 48 ('device_isMobile', 157)
# 49 ('weekday_unique_s_count', 157)
# 50 ('geoNetwork_subContinent', 147)
# 51 ('totals_bounces', 130)
# 52 ('channelGrouping', 125)
# 53 ('weekofmonth', 122)
# 54 ('trafficSource_keyword', 91)
# 55 ('count_hits_per_network_domain', 52)
# 56 ('campaign_medium', 51)
# 57 ('medium_hits_max', 27)
# 58 ('geoNetwork_continent', 17)
# 59 ('trafficSource_medium', 16)
# 60 ('device_browser', 10)
# 61 ('min_hits_per_day', 0)
# 62 ('min_hits_per_hour', 0)
# 63 ('medium_hits_min', 0)
# raw_train: results/2018-09-26T224046__T1.446_V1.593_K/reg_train_2018-09-26T224046.csv
# raw_test: results/2018-09-26T224046__T1.446_V1.593_K/reg_test_2018-09-26T224046.csv
# submit: results/2018-09-26T224046__T1.446_V1.593_K/aiden_2018-09-26T224046.csv.tar.gz
# cp -f reg_lgbm.ipynb results/2018-09-26T224046__T1.446_V1.593_K/reg_lgbm.ipynb
#
# results/2018-09-26T224046__T1.446_V1.593_K/aiden_2018-09-26T224046.csv.tar.gz
# Fold: KFold_02
# Training until validation scores don't improve for 100 rounds.
# [25]	train's rmse: 1.86263	valid's rmse: 1.87468
# [50]	train's rmse: 1.76476	valid's rmse: 1.78633
# [75]	train's rmse: 1.69353	valid's rmse: 1.72632
# [100]	train's rmse: 1.6428	valid's rmse: 1.68731
# [125]	train's rmse: 1.60555	valid's rmse: 1.66105
# [150]	train's rmse: 1.57664	valid's rmse: 1.64319
# [175]	train's rmse: 1.55367	valid's rmse: 1.6311
# [200]	train's rmse: 1.53549	valid's rmse: 1.62277
# [225]	train's rmse: 1.52039	valid's rmse: 1.61661
# [250]	train's rmse: 1.50748	valid's rmse: 1.6122
# [275]	train's rmse: 1.49577	valid's rmse: 1.60885
# [300]	train's rmse: 1.48617	valid's rmse: 1.60663
# [325]	train's rmse: 1.47819	valid's rmse: 1.60532
# [350]	train's rmse: 1.4709	valid's rmse: 1.60435
# [375]	train's rmse: 1.46473	valid's rmse: 1.60365
# [400]	train's rmse: 1.45893	valid's rmse: 1.60312
# [425]	train's rmse: 1.45466	valid's rmse: 1.60291
# [450]	train's rmse: 1.45113	valid's rmse: 1.6028
# [475]	train's rmse: 1.44804	valid's rmse: 1.60272
# [500]	train's rmse: 1.44572	valid's rmse: 1.603
# Did not meet early stopping. Best iteration is:
# [500]	train's rmse: 1.44572	valid's rmse: 1.603
# predict train set
# predict test set
# <feature_importance>
# 0 ('totals_pageviews_hit_rate', 8255)
# 1 ('totals_pageviews', 6911)
# 2 ('visitNumber', 4538)
# 3 ('totals_hits', 4393)
# 4 ('weekofyear', 4196)
# 5 ('geoNetwork_city', 3905)
# 6 ('geoNetwork_networkDomain', 3102)
# 7 ('source_country', 2805)
# 8 ('user_hour_mean', 2338)
# 9 ('browser_operatingSystem', 1693)
# 10 ('hour_unique_user_count', 1638)
# 11 ('user_hour_max', 1627)
# 12 ('mean_hits_per_day', 1567)
# 13 ('month', 1534)
# 14 ('user_hour_min', 1523)
# 15 ('max_hits_per_day', 1484)
# 16 ('var_hits_per_day', 1451)
# 17 ('day', 1436)
# 18 ('month_unique_user_count', 1383)
# 19 ('mean_hour_per_browser_operatingSystem', 1358)
# 20 ('day_unique_user_count', 1286)
# 21 ('max_hits_per_hour', 1202)
# 22 ('mean_hits_per_hour', 1131)
# 23 ('mean_pageviews_per_network_domain', 1129)
# 24 ('sum_pageviews_per_network_domain', 1108)
# 25 ('hour', 1024)
# 26 ('sum_hits_per_hour', 1024)
# 27 ('trafficSource_isTrueDirect', 1003)
# 28 ('sum_hits_per_day', 996)
# 29 ('day_unique_s_count', 897)
# 30 ('var_hits_per_hour', 842)
# 31 ('weekday', 835)
# 32 ('weekday_unique_user_count', 778)
# 33 ('geoNetwork_metro', 695)
# 34 ('geoNetwork_region', 680)
# 35 ('mean_hits_per_network_domain', 597)
# 36 ('medium_hits_mean', 588)
# 37 ('geoNetwork_country', 587)
# 38 ('totals_newVisits', 511)
# 39 ('month_unique_s_count', 470)
# 40 ('count_pageviews_per_network_domain', 463)
# 41 ('trafficSource_source', 430)
# 42 ('hour_unique_s_count', 389)
# 43 ('browser_category', 318)
# 44 ('medium_hits_sum', 287)
# 45 ('device_operatingSystem', 278)
# 46 ('device_deviceCategory', 250)
# 47 ('totals_bounces', 180)
# 48 ('geoNetwork_subContinent', 163)
# 49 ('sum_hits_per_network_domain', 160)
# 50 ('weekday_unique_s_count', 154)
# 51 ('channelGrouping', 123)
# 52 ('device_isMobile', 114)
# 53 ('weekofmonth', 105)
# 54 ('trafficSource_keyword', 65)
# 55 ('count_hits_per_network_domain', 50)
# 56 ('campaign_medium', 50)
# 57 ('trafficSource_medium', 29)
# 58 ('geoNetwork_continent', 28)
# 59 ('device_browser', 25)
# 60 ('medium_hits_max', 22)
# 61 ('min_hits_per_day', 0)
# 62 ('min_hits_per_hour', 0)
# 63 ('medium_hits_min', 0)
# raw_train: results/2018-09-26T224202__T1.446_V1.603_K/reg_train_2018-09-26T224202.csv
# raw_test: results/2018-09-26T224202__T1.446_V1.603_K/reg_test_2018-09-26T224202.csv
# submit: results/2018-09-26T224202__T1.446_V1.603_K/aiden_2018-09-26T224202.csv.tar.gz
# cp -f reg_lgbm.ipynb results/2018-09-26T224202__T1.446_V1.603_K/reg_lgbm.ipynb
#
# results/2018-09-26T224202__T1.446_V1.603_K/aiden_2018-09-26T224202.csv.tar.gz
# Fold: KFold_03
# Training until validation scores don't improve for 100 rounds.
# [25]	train's rmse: 1.85693	valid's rmse: 1.9
# [50]	train's rmse: 1.75912	valid's rmse: 1.81044
# [75]	train's rmse: 1.68831	valid's rmse: 1.74913
# [100]	train's rmse: 1.63852	valid's rmse: 1.70871
# [125]	train's rmse: 1.60172	valid's rmse: 1.68153
# [150]	train's rmse: 1.57256	valid's rmse: 1.6621
# [175]	train's rmse: 1.54974	valid's rmse: 1.64893
# [200]	train's rmse: 1.53134	valid's rmse: 1.63952
# [225]	train's rmse: 1.51574	valid's rmse: 1.63297
# [250]	train's rmse: 1.50246	valid's rmse: 1.62813
# [275]	train's rmse: 1.49079	valid's rmse: 1.62467
# [300]	train's rmse: 1.48137	valid's rmse: 1.62222
# [325]	train's rmse: 1.47314	valid's rmse: 1.62028
# [350]	train's rmse: 1.46584	valid's rmse: 1.61896
# [375]	train's rmse: 1.45977	valid's rmse: 1.61799
# [400]	train's rmse: 1.45443	valid's rmse: 1.61746
# [425]	train's rmse: 1.44988	valid's rmse: 1.61708
# [450]	train's rmse: 1.44657	valid's rmse: 1.61702
# [475]	train's rmse: 1.44327	valid's rmse: 1.61689
# [500]	train's rmse: 1.44089	valid's rmse: 1.61713
# Did not meet early stopping. Best iteration is:
# [500]	train's rmse: 1.44089	valid's rmse: 1.61713
# predict train set
# predict test set
# <feature_importance>
# 0 ('totals_pageviews_hit_rate', 8463)
# 1 ('totals_pageviews', 6890)
# 2 ('visitNumber', 4516)
# 3 ('totals_hits', 4495)
# 4 ('weekofyear', 4435)
# 5 ('geoNetwork_city', 3834)
# 6 ('geoNetwork_networkDomain', 3059)
# 7 ('source_country', 2704)
# 8 ('user_hour_mean', 2344)
# 9 ('browser_operatingSystem', 1796)
# 10 ('user_hour_max', 1770)
# 11 ('day', 1656)
# 12 ('user_hour_min', 1623)
# 13 ('hour_unique_user_count', 1581)
# 14 ('month', 1454)
# 15 ('month_unique_user_count', 1451)
# 16 ('mean_hits_per_day', 1440)
# 17 ('var_hits_per_day', 1341)
# 18 ('max_hits_per_day', 1297)
# 19 ('mean_hour_per_browser_operatingSystem', 1278)
# 20 ('day_unique_user_count', 1251)
# 21 ('max_hits_per_hour', 1144)
# 22 ('hour', 1117)
# 23 ('mean_pageviews_per_network_domain', 1101)
# 24 ('sum_hits_per_hour', 1085)
# 25 ('mean_hits_per_hour', 1067)
# 26 ('trafficSource_isTrueDirect', 1062)
# 27 ('sum_pageviews_per_network_domain', 1037)
# 28 ('sum_hits_per_day', 911)
# 29 ('day_unique_s_count', 906)
# 30 ('weekday', 895)
# 31 ('var_hits_per_hour', 868)
# 32 ('geoNetwork_metro', 826)
# 33 ('weekday_unique_user_count', 718)
# 34 ('geoNetwork_country', 683)
# 35 ('geoNetwork_region', 605)
# 36 ('trafficSource_source', 583)
# 37 ('mean_hits_per_network_domain', 582)
# 38 ('medium_hits_mean', 560)
# 39 ('month_unique_s_count', 541)
# 40 ('totals_newVisits', 469)
# 41 ('count_pageviews_per_network_domain', 458)
# 42 ('hour_unique_s_count', 420)
# 43 ('medium_hits_sum', 359)
# 44 ('device_operatingSystem', 351)
# 45 ('browser_category', 340)
# 46 ('device_deviceCategory', 269)
# 47 ('geoNetwork_subContinent', 192)
# 48 ('totals_bounces', 179)
# 49 ('weekday_unique_s_count', 138)
# 50 ('device_isMobile', 127)
# 51 ('channelGrouping', 125)
# 52 ('sum_hits_per_network_domain', 111)
# 53 ('weekofmonth', 100)
# 54 ('trafficSource_keyword', 84)
# 55 ('campaign_medium', 56)
# 56 ('count_hits_per_network_domain', 53)
# 57 ('trafficSource_medium', 15)
# 58 ('geoNetwork_continent', 14)
# 59 ('medium_hits_max', 10)
# 60 ('device_browser', 7)
# 61 ('min_hits_per_day', 0)
# 62 ('min_hits_per_hour', 0)
# 63 ('medium_hits_min', 0)
# raw_train: results/2018-09-26T224320__T1.441_V1.617_K/reg_train_2018-09-26T224320.csv
# raw_test: results/2018-09-26T224320__T1.441_V1.617_K/reg_test_2018-09-26T224320.csv
# submit: results/2018-09-26T224320__T1.441_V1.617_K/aiden_2018-09-26T224320.csv.tar.gz
# cp -f reg_lgbm.ipynb results/2018-09-26T224320__T1.441_V1.617_K/reg_lgbm.ipynb
#
# results/2018-09-26T224320__T1.441_V1.617_K/aiden_2018-09-26T224320.csv.tar.gz
# Fold: KFold_04
# Training until validation scores don't improve for 100 rounds.
# [25]	train's rmse: 1.86989	valid's rmse: 1.8487
# [50]	train's rmse: 1.77162	valid's rmse: 1.7627
# [75]	train's rmse: 1.7001	valid's rmse: 1.70373
# [100]	train's rmse: 1.64991	valid's rmse: 1.66533
# [125]	train's rmse: 1.61253	valid's rmse: 1.63924
# [150]	train's rmse: 1.58266	valid's rmse: 1.62106
# [175]	train's rmse: 1.56014	valid's rmse: 1.60871
# [200]	train's rmse: 1.54126	valid's rmse: 1.59981
# [225]	train's rmse: 1.52569	valid's rmse: 1.59336
# [250]	train's rmse: 1.51263	valid's rmse: 1.58894
# [275]	train's rmse: 1.50077	valid's rmse: 1.58556
# [300]	train's rmse: 1.49099	valid's rmse: 1.58298
# [325]	train's rmse: 1.48265	valid's rmse: 1.58111
# [350]	train's rmse: 1.47533	valid's rmse: 1.57956
# [375]	train's rmse: 1.46903	valid's rmse: 1.57845
# [400]	train's rmse: 1.4639	valid's rmse: 1.57785
# [425]	train's rmse: 1.45969	valid's rmse: 1.57766
# [450]	train's rmse: 1.45588	valid's rmse: 1.57751
# [475]	train's rmse: 1.45235	valid's rmse: 1.57766
# [500]	train's rmse: 1.44958	valid's rmse: 1.5777
# Did not meet early stopping. Best iteration is:
# [500]	train's rmse: 1.44958	valid's rmse: 1.5777
# predict train set
# predict test set
# <feature_importance>
# 0 ('totals_pageviews_hit_rate', 8264)
# 1 ('totals_pageviews', 7133)
# 2 ('totals_hits', 4596)
# 3 ('visitNumber', 4259)
# 4 ('geoNetwork_city', 3832)
# 5 ('weekofyear', 3805)
# 6 ('geoNetwork_networkDomain', 3193)
# 7 ('source_country', 2870)
# 8 ('user_hour_mean', 2714)
# 9 ('user_hour_max', 1847)
# 10 ('user_hour_min', 1784)
# 11 ('hour_unique_user_count', 1708)
# 12 ('browser_operatingSystem', 1611)
# 13 ('mean_hits_per_day', 1549)
# 14 ('month', 1495)
# 15 ('day', 1484)
# 16 ('month_unique_user_count', 1452)
# 17 ('var_hits_per_day', 1347)
# 18 ('max_hits_per_day', 1346)
# 19 ('day_unique_user_count', 1265)
# 20 ('max_hits_per_hour', 1242)
# 21 ('mean_hour_per_browser_operatingSystem', 1230)
# 22 ('mean_pageviews_per_network_domain', 1133)
# 23 ('mean_hits_per_hour', 1086)
# 24 ('sum_hits_per_hour', 1080)
# 25 ('hour', 1059)
# 26 ('sum_pageviews_per_network_domain', 1039)
# 27 ('trafficSource_isTrueDirect', 956)
# 28 ('sum_hits_per_day', 947)
# 29 ('var_hits_per_hour', 902)
# 30 ('day_unique_s_count', 871)
# 31 ('weekday', 860)
# 32 ('geoNetwork_metro', 814)
# 33 ('weekday_unique_user_count', 747)
# 34 ('geoNetwork_country', 646)
# 35 ('geoNetwork_region', 590)
# 36 ('mean_hits_per_network_domain', 559)
# 37 ('medium_hits_mean', 536)
# 38 ('trafficSource_source', 491)
# 39 ('totals_newVisits', 482)
# 40 ('count_pageviews_per_network_domain', 466)
# 41 ('month_unique_s_count', 464)
# 42 ('hour_unique_s_count', 419)
# 43 ('browser_category', 338)
# 44 ('device_operatingSystem', 328)
# 45 ('medium_hits_sum', 285)
# 46 ('device_deviceCategory', 275)
# 47 ('totals_bounces', 183)
# 48 ('geoNetwork_subContinent', 160)
# 49 ('weekday_unique_s_count', 155)
# 50 ('sum_hits_per_network_domain', 146)
# 51 ('weekofmonth', 116)
# 52 ('channelGrouping', 111)
# 53 ('trafficSource_keyword', 100)
# 54 ('device_isMobile', 90)
# 55 ('campaign_medium', 69)
# 56 ('count_hits_per_network_domain', 50)
# 57 ('medium_hits_max', 19)
# 58 ('device_browser', 17)
# 59 ('trafficSource_medium', 14)
# 60 ('geoNetwork_continent', 10)
# 61 ('min_hits_per_day', 0)
# 62 ('min_hits_per_hour', 0)
# 63 ('medium_hits_min', 0)
# raw_train: results/2018-09-26T224437__T1.450_V1.578_K/reg_train_2018-09-26T224437.csv
# raw_test: results/2018-09-26T224437__T1.450_V1.578_K/reg_test_2018-09-26T224437.csv
# submit: results/2018-09-26T224437__T1.450_V1.578_K/aiden_2018-09-26T224437.csv.tar.gz
# cp -f reg_lgbm.ipynb results/2018-09-26T224437__T1.450_V1.578_K/reg_lgbm.ipynb
#
# results/2018-09-26T224437__T1.450_V1.578_K/aiden_2018-09-26T224437.csv.tar.gz

# %% [markdown]
# ### StratifiedKFold

# %%
folds = StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=7)
y_categorized = np.digitize(df_train_y.values, bins=np.arange(2,24,2))

for fold_n, (train_index, test_index) in enumerate(folds.split(df_train_X, y_categorized)):
    fold_col = 'StratifiedKFold_{0:02d}'.format(fold_n)
    fold_cols.append(fold_col)
    print('Fold:', fold_col)

    X_train, X_valid = df_train_X.iloc[train_index], df_train_X.iloc[test_index]
    y_train, y_valid = df_train_y.iloc[train_index], df_train_y.iloc[test_index]
    
    model = modeling(fold_col, X_train, X_valid, y_train, y_valid)
# Out:
# /Users/hyundai/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_split.py:605: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# Fold: StratifiedKFold_00
# /Users/hyundai/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py:1158: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# /Users/hyundai/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py:725: UserWarning: categorical_feature in param dict is overridden.
#   warnings.warn('categorical_feature in param dict is overridden.')
# Training until validation scores don't improve for 100 rounds.
# [25]	train's rmse: 1.86416	valid's rmse: 1.87081
# [50]	train's rmse: 1.7667	valid's rmse: 1.78175
# [75]	train's rmse: 1.69559	valid's rmse: 1.72043
# [100]	train's rmse: 1.64523	valid's rmse: 1.68051
# [125]	train's rmse: 1.60769	valid's rmse: 1.65385
# [150]	train's rmse: 1.57808	valid's rmse: 1.63531
# [175]	train's rmse: 1.55476	valid's rmse: 1.62269
# [200]	train's rmse: 1.53595	valid's rmse: 1.61414
# [225]	train's rmse: 1.51993	valid's rmse: 1.60843
# [250]	train's rmse: 1.50648	valid's rmse: 1.60396
# [275]	train's rmse: 1.4941	valid's rmse: 1.60111
# [300]	train's rmse: 1.48433	valid's rmse: 1.59932
# [325]	train's rmse: 1.47565	valid's rmse: 1.59812
# [350]	train's rmse: 1.46774	valid's rmse: 1.59706
# [375]	train's rmse: 1.46113	valid's rmse: 1.59635
# [400]	train's rmse: 1.45532	valid's rmse: 1.59589
# [425]	train's rmse: 1.45029	valid's rmse: 1.59564
# [450]	train's rmse: 1.44658	valid's rmse: 1.59537
# [475]	train's rmse: 1.4443	valid's rmse: 1.59512
# [500]	train's rmse: 1.44231	valid's rmse: 1.59509
# Did not meet early stopping. Best iteration is:
# [500]	train's rmse: 1.44231	valid's rmse: 1.59509
# predict train set
# predict test set
# <feature_importance>
# 0 ('totals_pageviews_hit_rate', 7921)
# 1 ('totals_pageviews', 7132)
# 2 ('totals_hits', 4414)
# 3 ('visitNumber', 4225)
# 4 ('weekofyear', 4109)
# 5 ('geoNetwork_city', 3810)
# 6 ('geoNetwork_networkDomain', 3166)
# 7 ('source_country', 2803)
# 8 ('user_hour_mean', 2557)
# 9 ('user_hour_max', 1833)
# 10 ('user_hour_min', 1711)
# 11 ('browser_operatingSystem', 1685)
# 12 ('hour_unique_user_count', 1645)
# 13 ('day', 1541)
# 14 ('month', 1531)
# 15 ('month_unique_user_count', 1478)
# 16 ('mean_hits_per_day', 1477)
# 17 ('max_hits_per_day', 1410)
# 18 ('var_hits_per_day', 1348)
# 19 ('day_unique_user_count', 1314)
# 20 ('max_hits_per_hour', 1265)
# 21 ('mean_hour_per_browser_operatingSystem', 1255)
# 22 ('mean_pageviews_per_network_domain', 1238)
# 23 ('hour', 1115)
# 24 ('sum_hits_per_hour', 1099)
# 25 ('sum_pageviews_per_network_domain', 1060)
# 26 ('mean_hits_per_hour', 1016)
# 27 ('trafficSource_isTrueDirect', 999)
# 28 ('day_unique_s_count', 944)
# 29 ('sum_hits_per_day', 895)
# 30 ('weekday', 846)
# 31 ('weekday_unique_user_count', 820)
# 32 ('var_hits_per_hour', 772)
# 33 ('geoNetwork_metro', 767)
# 34 ('geoNetwork_country', 628)
# 35 ('geoNetwork_region', 603)
# 36 ('medium_hits_mean', 599)
# 37 ('mean_hits_per_network_domain', 581)
# 38 ('trafficSource_source', 489)
# 39 ('month_unique_s_count', 470)
# 40 ('totals_newVisits', 466)
# 41 ('count_pageviews_per_network_domain', 463)
# 42 ('hour_unique_s_count', 406)
# 43 ('device_operatingSystem', 348)
# 44 ('medium_hits_sum', 317)
# 45 ('browser_category', 279)
# 46 ('device_deviceCategory', 242)
# 47 ('totals_bounces', 172)
# 48 ('sum_hits_per_network_domain', 167)
# 49 ('weekday_unique_s_count', 153)
# 50 ('geoNetwork_subContinent', 151)
# 51 ('device_isMobile', 133)
# 52 ('channelGrouping', 130)
# 53 ('weekofmonth', 122)
# 54 ('trafficSource_keyword', 88)
# 55 ('campaign_medium', 47)
# 56 ('count_hits_per_network_domain', 41)
# 57 ('trafficSource_medium', 28)
# 58 ('geoNetwork_continent', 20)
# 59 ('medium_hits_max', 16)
# 60 ('device_browser', 10)
# 61 ('min_hits_per_day', 0)
# 62 ('min_hits_per_hour', 0)
# 63 ('medium_hits_min', 0)
# raw_train: results/2018-09-26T224555__T1.442_V1.595_K/reg_train_2018-09-26T224555.csv
# raw_test: results/2018-09-26T224555__T1.442_V1.595_K/reg_test_2018-09-26T224555.csv
# submit: results/2018-09-26T224555__T1.442_V1.595_K/aiden_2018-09-26T224555.csv.tar.gz
# cp -f reg_lgbm.ipynb results/2018-09-26T224555__T1.442_V1.595_K/reg_lgbm.ipynb
#
# results/2018-09-26T224555__T1.442_V1.595_K/aiden_2018-09-26T224555.csv.tar.gz
# Fold: StratifiedKFold_01
# Training until validation scores don't improve for 100 rounds.
# [25]	train's rmse: 1.86429	valid's rmse: 1.8716
# [50]	train's rmse: 1.76711	valid's rmse: 1.78312
# [75]	train's rmse: 1.69647	valid's rmse: 1.7219
# [100]	train's rmse: 1.64653	valid's rmse: 1.68156
# [125]	train's rmse: 1.60961	valid's rmse: 1.65428
# [150]	train's rmse: 1.58002	valid's rmse: 1.63508
# [175]	train's rmse: 1.55664	valid's rmse: 1.62207
# [200]	train's rmse: 1.53812	valid's rmse: 1.61327
# [225]	train's rmse: 1.52306	valid's rmse: 1.60687
# [250]	train's rmse: 1.50968	valid's rmse: 1.60199
# [275]	train's rmse: 1.49784	valid's rmse: 1.59871
# [300]	train's rmse: 1.48826	valid's rmse: 1.59654
# [325]	train's rmse: 1.47968	valid's rmse: 1.59494
# [350]	train's rmse: 1.47228	valid's rmse: 1.59364
# [375]	train's rmse: 1.4664	valid's rmse: 1.59277
# [400]	train's rmse: 1.46109	valid's rmse: 1.59211
# [425]	train's rmse: 1.45609	valid's rmse: 1.59151
# [450]	train's rmse: 1.45218	valid's rmse: 1.5911
# [475]	train's rmse: 1.44868	valid's rmse: 1.59082
# [500]	train's rmse: 1.44626	valid's rmse: 1.59086
# Did not meet early stopping. Best iteration is:
# [500]	train's rmse: 1.44626	valid's rmse: 1.59086
# predict train set
# predict test set
# <feature_importance>
# 0 ('totals_pageviews_hit_rate', 8186)
# 1 ('totals_pageviews', 7019)
# 2 ('totals_hits', 4658)
# 3 ('visitNumber', 4463)
# 4 ('weekofyear', 4181)
# 5 ('geoNetwork_city', 3991)
# 6 ('geoNetwork_networkDomain', 3164)
# 7 ('source_country', 2841)
# 8 ('user_hour_mean', 2619)
# 9 ('user_hour_max', 1837)
# 10 ('browser_operatingSystem', 1753)
# 11 ('month', 1658)
# 12 ('hour_unique_user_count', 1655)
# 13 ('user_hour_min', 1603)
# 14 ('day', 1591)
# 15 ('var_hits_per_day', 1544)
# 16 ('mean_hits_per_day', 1541)
# 17 ('month_unique_user_count', 1519)
# 18 ('day_unique_user_count', 1356)
# 19 ('mean_hour_per_browser_operatingSystem', 1328)
# 20 ('max_hits_per_day', 1303)
# 21 ('mean_pageviews_per_network_domain', 1156)
# 22 ('mean_hits_per_hour', 1097)
# 23 ('max_hits_per_hour', 1081)
# 24 ('sum_pageviews_per_network_domain', 1073)
# 25 ('hour', 1058)
# 26 ('sum_hits_per_day', 953)
# 27 ('sum_hits_per_hour', 946)
# 28 ('day_unique_s_count', 937)
# 29 ('weekday', 936)
# 30 ('trafficSource_isTrueDirect', 896)
# 31 ('var_hits_per_hour', 782)
# 32 ('geoNetwork_metro', 734)
# 33 ('weekday_unique_user_count', 727)
# 34 ('geoNetwork_region', 678)
# 35 ('medium_hits_mean', 623)
# 36 ('geoNetwork_country', 584)
# 37 ('mean_hits_per_network_domain', 533)
# 38 ('totals_newVisits', 515)
# 39 ('trafficSource_source', 498)
# 40 ('month_unique_s_count', 483)
# 41 ('hour_unique_s_count', 445)
# 42 ('count_pageviews_per_network_domain', 437)
# 43 ('medium_hits_sum', 356)
# 44 ('device_operatingSystem', 324)
# 45 ('browser_category', 307)
# 46 ('device_deviceCategory', 249)
# 47 ('sum_hits_per_network_domain', 173)
# 48 ('totals_bounces', 144)
# 49 ('weekday_unique_s_count', 118)
# 50 ('weekofmonth', 116)
# 51 ('channelGrouping', 115)
# 52 ('geoNetwork_subContinent', 112)
# 53 ('device_isMobile', 103)
# 54 ('trafficSource_keyword', 90)
# 55 ('campaign_medium', 74)
# 56 ('count_hits_per_network_domain', 59)
# 57 ('trafficSource_medium', 25)
# 58 ('geoNetwork_continent', 21)
# 59 ('medium_hits_max', 19)
# 60 ('device_browser', 15)
# 61 ('min_hits_per_day', 0)
# 62 ('min_hits_per_hour', 0)
# 63 ('medium_hits_min', 0)
# raw_train: results/2018-09-26T224713__T1.446_V1.591_K/reg_train_2018-09-26T224713.csv
# raw_test: results/2018-09-26T224713__T1.446_V1.591_K/reg_test_2018-09-26T224713.csv
# submit: results/2018-09-26T224713__T1.446_V1.591_K/aiden_2018-09-26T224713.csv.tar.gz
# cp -f reg_lgbm.ipynb results/2018-09-26T224713__T1.446_V1.591_K/reg_lgbm.ipynb
#
# results/2018-09-26T224713__T1.446_V1.591_K/aiden_2018-09-26T224713.csv.tar.gz
# Fold: StratifiedKFold_02
# Training until validation scores don't improve for 100 rounds.
# [25]	train's rmse: 1.86321	valid's rmse: 1.87424
# [50]	train's rmse: 1.76476	valid's rmse: 1.78654
# [75]	train's rmse: 1.6933	valid's rmse: 1.72663
# [100]	train's rmse: 1.64348	valid's rmse: 1.6873
# [125]	train's rmse: 1.60636	valid's rmse: 1.6609
# [150]	train's rmse: 1.57697	valid's rmse: 1.64241
# [175]	train's rmse: 1.5543	valid's rmse: 1.63007
# [200]	train's rmse: 1.53573	valid's rmse: 1.62142
# [225]	train's rmse: 1.52036	valid's rmse: 1.61561
# [250]	train's rmse: 1.50637	valid's rmse: 1.61161
# [275]	train's rmse: 1.49478	valid's rmse: 1.60855
# [300]	train's rmse: 1.48507	valid's rmse: 1.60653
# [325]	train's rmse: 1.4767	valid's rmse: 1.60515
# [350]	train's rmse: 1.4693	valid's rmse: 1.60404
# [375]	train's rmse: 1.46318	valid's rmse: 1.60333
# [400]	train's rmse: 1.45793	valid's rmse: 1.6026
# [425]	train's rmse: 1.45372	valid's rmse: 1.60219
# [450]	train's rmse: 1.4505	valid's rmse: 1.60185
# [475]	train's rmse: 1.44731	valid's rmse: 1.60158
# [500]	train's rmse: 1.44474	valid's rmse: 1.60163
# Did not meet early stopping. Best iteration is:
# [500]	train's rmse: 1.44474	valid's rmse: 1.60163
# predict train set
# predict test set
# <feature_importance>
# 0 ('totals_pageviews_hit_rate', 8202)
# 1 ('totals_pageviews', 7065)
# 2 ('totals_hits', 4570)
# 3 ('visitNumber', 4296)
# 4 ('weekofyear', 3994)
# 5 ('geoNetwork_city', 3981)
# 6 ('geoNetwork_networkDomain', 3180)
# 7 ('source_country', 2786)
# 8 ('user_hour_mean', 2400)
# 9 ('browser_operatingSystem', 1758)
# 10 ('user_hour_max', 1757)
# 11 ('month', 1584)
# 12 ('user_hour_min', 1572)
# 13 ('mean_hits_per_day', 1538)
# 14 ('hour_unique_user_count', 1509)
# 15 ('month_unique_user_count', 1479)
# 16 ('var_hits_per_day', 1420)
# 17 ('max_hits_per_day', 1387)
# 18 ('day', 1365)
# 19 ('max_hits_per_hour', 1297)
# 20 ('day_unique_user_count', 1282)
# 21 ('mean_hour_per_browser_operatingSystem', 1218)
# 22 ('mean_hits_per_hour', 1183)
# 23 ('sum_pageviews_per_network_domain', 1083)
# 24 ('sum_hits_per_hour', 1042)
# 25 ('mean_pageviews_per_network_domain', 1015)
# 26 ('trafficSource_isTrueDirect', 1011)
# 27 ('hour', 988)
# 28 ('day_unique_s_count', 977)
# 29 ('sum_hits_per_day', 969)
# 30 ('weekday', 836)
# 31 ('var_hits_per_hour', 831)
# 32 ('geoNetwork_metro', 798)
# 33 ('weekday_unique_user_count', 716)
# 34 ('medium_hits_mean', 690)
# 35 ('geoNetwork_region', 651)
# 36 ('geoNetwork_country', 591)
# 37 ('mean_hits_per_network_domain', 572)
# 38 ('trafficSource_source', 524)
# 39 ('totals_newVisits', 497)
# 40 ('count_pageviews_per_network_domain', 480)
# 41 ('month_unique_s_count', 465)
# 42 ('hour_unique_s_count', 442)
# 43 ('device_operatingSystem', 380)
# 44 ('device_deviceCategory', 306)
# 45 ('browser_category', 289)
# 46 ('medium_hits_sum', 279)
# 47 ('geoNetwork_subContinent', 210)
# 48 ('totals_bounces', 179)
# 49 ('weekday_unique_s_count', 146)
# 50 ('sum_hits_per_network_domain', 143)
# 51 ('device_isMobile', 141)
# 52 ('channelGrouping', 120)
# 53 ('weekofmonth', 96)
# 54 ('trafficSource_keyword', 76)
# 55 ('campaign_medium', 46)
# 56 ('count_hits_per_network_domain', 41)
# 57 ('geoNetwork_continent', 19)
# 58 ('trafficSource_medium', 18)
# 59 ('medium_hits_max', 14)
# 60 ('device_browser', 10)
# 61 ('min_hits_per_day', 0)
# 62 ('min_hits_per_hour', 0)
# 63 ('medium_hits_min', 0)
# raw_train: results/2018-09-26T224831__T1.445_V1.602_K/reg_train_2018-09-26T224831.csv
# raw_test: results/2018-09-26T224831__T1.445_V1.602_K/reg_test_2018-09-26T224831.csv
# submit: results/2018-09-26T224831__T1.445_V1.602_K/aiden_2018-09-26T224831.csv.tar.gz
# cp -f reg_lgbm.ipynb results/2018-09-26T224831__T1.445_V1.602_K/reg_lgbm.ipynb
#
# results/2018-09-26T224831__T1.445_V1.602_K/aiden_2018-09-26T224831.csv.tar.gz
# Fold: StratifiedKFold_03
# Training until validation scores don't improve for 100 rounds.
# [25]	train's rmse: 1.86214	valid's rmse: 1.87538
# [50]	train's rmse: 1.7631	valid's rmse: 1.7892
# [75]	train's rmse: 1.69165	valid's rmse: 1.73072
# [100]	train's rmse: 1.64074	valid's rmse: 1.69253
# [125]	train's rmse: 1.60317	valid's rmse: 1.66747
# [150]	train's rmse: 1.5739	valid's rmse: 1.6502
# [175]	train's rmse: 1.55123	valid's rmse: 1.63803
# [200]	train's rmse: 1.53252	valid's rmse: 1.63031
# [225]	train's rmse: 1.51697	valid's rmse: 1.62502
# [250]	train's rmse: 1.50339	valid's rmse: 1.62145
# [275]	train's rmse: 1.4914	valid's rmse: 1.61893
# [300]	train's rmse: 1.48173	valid's rmse: 1.61725
# [325]	train's rmse: 1.47328	valid's rmse: 1.61577
# [350]	train's rmse: 1.46559	valid's rmse: 1.61505
# [375]	train's rmse: 1.45927	valid's rmse: 1.61468
# [400]	train's rmse: 1.45438	valid's rmse: 1.61415
# [425]	train's rmse: 1.44999	valid's rmse: 1.61419
# [450]	train's rmse: 1.44623	valid's rmse: 1.61421
# [475]	train's rmse: 1.44272	valid's rmse: 1.61424
# [500]	train's rmse: 1.4406	valid's rmse: 1.6146
# Did not meet early stopping. Best iteration is:
# [500]	train's rmse: 1.4406	valid's rmse: 1.6146
# predict train set
# predict test set
# <feature_importance>
# 0 ('totals_pageviews_hit_rate', 8098)
# 1 ('totals_pageviews', 7025)
# 2 ('visitNumber', 4420)
# 3 ('totals_hits', 4367)
# 4 ('weekofyear', 4196)
# 5 ('geoNetwork_city', 3797)
# 6 ('geoNetwork_networkDomain', 3003)
# 7 ('source_country', 2789)
# 8 ('user_hour_mean', 2481)
# 9 ('browser_operatingSystem', 1877)
# 10 ('user_hour_max', 1858)
# 11 ('user_hour_min', 1698)
# 12 ('hour_unique_user_count', 1576)
# 13 ('mean_hits_per_day', 1561)
# 14 ('month', 1503)
# 15 ('month_unique_user_count', 1444)
# 16 ('day', 1432)
# 17 ('var_hits_per_day', 1421)
# 18 ('max_hits_per_day', 1367)
# 19 ('mean_hour_per_browser_operatingSystem', 1273)
# 20 ('day_unique_user_count', 1221)
# 21 ('max_hits_per_hour', 1207)
# 22 ('hour', 1155)
# 23 ('mean_hits_per_hour', 1130)
# 24 ('mean_pageviews_per_network_domain', 1113)
# 25 ('sum_pageviews_per_network_domain', 1076)
# 26 ('trafficSource_isTrueDirect', 1066)
# 27 ('sum_hits_per_hour', 1037)
# 28 ('var_hits_per_hour', 949)
# 29 ('sum_hits_per_day', 934)
# 30 ('weekday', 894)
# 31 ('day_unique_s_count', 882)
# 32 ('geoNetwork_metro', 789)
# 33 ('weekday_unique_user_count', 691)
# 34 ('geoNetwork_country', 654)
# 35 ('geoNetwork_region', 642)
# 36 ('medium_hits_mean', 597)
# 37 ('mean_hits_per_network_domain', 545)
# 38 ('trafficSource_source', 521)
# 39 ('month_unique_s_count', 502)
# 40 ('totals_newVisits', 470)
# 41 ('count_pageviews_per_network_domain', 441)
# 42 ('hour_unique_s_count', 408)
# 43 ('medium_hits_sum', 287)
# 44 ('device_operatingSystem', 269)
# 45 ('browser_category', 268)
# 46 ('device_deviceCategory', 242)
# 47 ('totals_bounces', 160)
# 48 ('geoNetwork_subContinent', 154)
# 49 ('sum_hits_per_network_domain', 149)
# 50 ('channelGrouping', 127)
# 51 ('weekday_unique_s_count', 121)
# 52 ('weekofmonth', 114)
# 53 ('device_isMobile', 83)
# 54 ('trafficSource_keyword', 78)
# 55 ('campaign_medium', 48)
# 56 ('count_hits_per_network_domain', 38)
# 57 ('medium_hits_max', 30)
# 58 ('geoNetwork_continent', 27)
# 59 ('trafficSource_medium', 12)
# 60 ('device_browser', 10)
# 61 ('min_hits_per_day', 0)
# 62 ('min_hits_per_hour', 0)
# 63 ('medium_hits_min', 0)
# raw_train: results/2018-09-26T224949__T1.441_V1.615_K/reg_train_2018-09-26T224949.csv
# raw_test: results/2018-09-26T224949__T1.441_V1.615_K/reg_test_2018-09-26T224949.csv
# submit: results/2018-09-26T224949__T1.441_V1.615_K/aiden_2018-09-26T224949.csv.tar.gz
# cp -f reg_lgbm.ipynb results/2018-09-26T224949__T1.441_V1.615_K/reg_lgbm.ipynb
#
# results/2018-09-26T224949__T1.441_V1.615_K/aiden_2018-09-26T224949.csv.tar.gz
# Fold: StratifiedKFold_04
# Training until validation scores don't improve for 100 rounds.
# [25]	train's rmse: 1.86343	valid's rmse: 1.87133
# [50]	train's rmse: 1.76585	valid's rmse: 1.78277
# [75]	train's rmse: 1.69556	valid's rmse: 1.72228
# [100]	train's rmse: 1.64567	valid's rmse: 1.68252
# [125]	train's rmse: 1.60846	valid's rmse: 1.65529
# [150]	train's rmse: 1.57899	valid's rmse: 1.63628
# [175]	train's rmse: 1.55589	valid's rmse: 1.62336
# [200]	train's rmse: 1.53674	valid's rmse: 1.61487
# [225]	train's rmse: 1.52093	valid's rmse: 1.60912
# [250]	train's rmse: 1.50763	valid's rmse: 1.60473
# [275]	train's rmse: 1.49568	valid's rmse: 1.60126
# [300]	train's rmse: 1.4858	valid's rmse: 1.59894
# [325]	train's rmse: 1.4777	valid's rmse: 1.59739
# [350]	train's rmse: 1.46995	valid's rmse: 1.59637
# [375]	train's rmse: 1.46396	valid's rmse: 1.59575
# [400]	train's rmse: 1.45872	valid's rmse: 1.59543
# [425]	train's rmse: 1.45495	valid's rmse: 1.59542
# [450]	train's rmse: 1.45151	valid's rmse: 1.59551
# [475]	train's rmse: 1.44869	valid's rmse: 1.59563
# [500]	train's rmse: 1.44684	valid's rmse: 1.5958
# Did not meet early stopping. Best iteration is:
# [500]	train's rmse: 1.44684	valid's rmse: 1.5958
# predict train set
# predict test set
# <feature_importance>
# 0 ('totals_pageviews_hit_rate', 8238)
# 1 ('totals_pageviews', 6820)
# 2 ('visitNumber', 4714)
# 3 ('totals_hits', 4432)
# 4 ('weekofyear', 4227)
# 5 ('geoNetwork_city', 3926)
# 6 ('geoNetwork_networkDomain', 3230)
# 7 ('source_country', 2792)
# 8 ('user_hour_mean', 2491)
# 9 ('user_hour_max', 1736)
# 10 ('hour_unique_user_count', 1683)
# 11 ('user_hour_min', 1669)
# 12 ('mean_hits_per_day', 1621)
# 13 ('browser_operatingSystem', 1613)
# 14 ('month', 1521)
# 15 ('var_hits_per_day', 1480)
# 16 ('day', 1473)
# 17 ('month_unique_user_count', 1399)
# 18 ('mean_hour_per_browser_operatingSystem', 1307)
# 19 ('day_unique_user_count', 1299)
# 20 ('max_hits_per_day', 1198)
# 21 ('max_hits_per_hour', 1183)
# 22 ('sum_hits_per_hour', 1121)
# 23 ('sum_pageviews_per_network_domain', 1108)
# 24 ('mean_hits_per_hour', 1057)
# 25 ('sum_hits_per_day', 1042)
# 26 ('hour', 1037)
# 27 ('mean_pageviews_per_network_domain', 1021)
# 28 ('trafficSource_isTrueDirect', 927)
# 29 ('day_unique_s_count', 920)
# 30 ('weekday', 859)
# 31 ('geoNetwork_metro', 734)
# 32 ('weekday_unique_user_count', 711)
# 33 ('var_hits_per_hour', 707)
# 34 ('geoNetwork_country', 677)
# 35 ('geoNetwork_region', 628)
# 36 ('medium_hits_mean', 597)
# 37 ('mean_hits_per_network_domain', 577)
# 38 ('totals_newVisits', 535)
# 39 ('trafficSource_source', 525)
# 40 ('count_pageviews_per_network_domain', 495)
# 41 ('month_unique_s_count', 452)
# 42 ('hour_unique_s_count', 450)
# 43 ('medium_hits_sum', 324)
# 44 ('device_operatingSystem', 307)
# 45 ('browser_category', 298)
# 46 ('device_deviceCategory', 237)
# 47 ('sum_hits_per_network_domain', 187)
# 48 ('geoNetwork_subContinent', 149)
# 49 ('device_isMobile', 135)
# 50 ('totals_bounces', 120)
# 51 ('weekday_unique_s_count', 114)
# 52 ('weekofmonth', 105)
# 53 ('channelGrouping', 98)
# 54 ('trafficSource_keyword', 76)
# 55 ('count_hits_per_network_domain', 56)
# 56 ('campaign_medium', 55)
# 57 ('geoNetwork_continent', 20)
# 58 ('trafficSource_medium', 19)
# 59 ('medium_hits_max', 15)
# 60 ('device_browser', 9)
# 61 ('min_hits_per_day', 0)
# 62 ('min_hits_per_hour', 0)
# 63 ('medium_hits_min', 0)
# raw_train: results/2018-09-26T225106__T1.447_V1.596_K/reg_train_2018-09-26T225106.csv
# raw_test: results/2018-09-26T225106__T1.447_V1.596_K/reg_test_2018-09-26T225106.csv
# submit: results/2018-09-26T225106__T1.447_V1.596_K/aiden_2018-09-26T225106.csv.tar.gz
# cp -f reg_lgbm.ipynb results/2018-09-26T225106__T1.447_V1.596_K/reg_lgbm.ipynb
#
# results/2018-09-26T225106__T1.447_V1.596_K/aiden_2018-09-26T225106.csv.tar.gz

# %% [markdown]
# ### GroupKFold

# %%
groups = df_train['date'].astype(str).str[:6].values
folds = GroupKFold(n_splits=len(np.unique(groups)))

for fold_n, (train_index, test_index) in enumerate(folds.split(df_train_X, df_train_y, groups)):
    fold_col = 'GroupKFold_{0:02d}'.format(fold_n)
    fold_cols.append(fold_col)
    print('Fold:', fold_col)

    X_train, X_valid = df_train_X.iloc[train_index], df_train_X.iloc[test_index]
    y_train, y_valid = df_train_y.iloc[train_index], df_train_y.iloc[test_index]
    
    model = modeling(fold_col, X_train, X_valid, y_train, y_valid)
# Out:
# Fold: GroupKFold_00
# /Users/hyundai/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py:1158: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# /Users/hyundai/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py:725: UserWarning: categorical_feature in param dict is overridden.
#   warnings.warn('categorical_feature in param dict is overridden.')
# Training until validation scores don't improve for 100 rounds.
# [25]	train's rmse: 1.91099	valid's rmse: 1.50199
# [50]	train's rmse: 1.81034	valid's rmse: 1.43628
# [75]	train's rmse: 1.73763	valid's rmse: 1.39247
# [100]	train's rmse: 1.68688	valid's rmse: 1.36383
# [125]	train's rmse: 1.64953	valid's rmse: 1.34556
# [150]	train's rmse: 1.62007	valid's rmse: 1.333
# [175]	train's rmse: 1.59698	valid's rmse: 1.32434
# [200]	train's rmse: 1.57849	valid's rmse: 1.31887
# [225]	train's rmse: 1.56329	valid's rmse: 1.31529
# [250]	train's rmse: 1.55015	valid's rmse: 1.31286
# [275]	train's rmse: 1.53892	valid's rmse: 1.31156
# [300]	train's rmse: 1.52953	valid's rmse: 1.31103
# [325]	train's rmse: 1.52164	valid's rmse: 1.31064
# [350]	train's rmse: 1.51445	valid's rmse: 1.31037
# [375]	train's rmse: 1.50796	valid's rmse: 1.31034
# [400]	train's rmse: 1.5029	valid's rmse: 1.31039
# [425]	train's rmse: 1.49859	valid's rmse: 1.3107
# [450]	train's rmse: 1.4953	valid's rmse: 1.31097
# Early stopping, best iteration is:
# [357]	train's rmse: 1.51265	valid's rmse: 1.31028
# predict train set
# predict test set
# <feature_importance>
# 0 ('totals_pageviews_hit_rate', 7295)
# 1 ('totals_pageviews', 5435)
# 2 ('visitNumber', 4109)
# 3 ('weekofyear', 3971)
# 4 ('geoNetwork_city', 3729)
# 5 ('totals_hits', 3635)
# 6 ('geoNetwork_networkDomain', 2671)
# 7 ('source_country', 2544)
# 8 ('user_hour_mean', 2007)
# 9 ('browser_operatingSystem', 1681)
# 10 ('user_hour_max', 1453)
# 11 ('hour_unique_user_count', 1447)
# 12 ('month', 1403)
# 13 ('mean_hits_per_day', 1353)
# 14 ('user_hour_min', 1350)
# 15 ('month_unique_user_count', 1287)
# 16 ('var_hits_per_day', 1221)
# 17 ('day', 1206)
# 18 ('mean_hour_per_browser_operatingSystem', 1157)
# 19 ('max_hits_per_day', 1036)
# 20 ('day_unique_user_count', 990)
# 21 ('max_hits_per_hour', 943)
# 22 ('hour', 903)
# 23 ('mean_hits_per_hour', 851)
# 24 ('trafficSource_isTrueDirect', 842)
# 25 ('sum_pageviews_per_network_domain', 823)
# 26 ('sum_hits_per_hour', 820)
# 27 ('mean_pageviews_per_network_domain', 810)
# 28 ('sum_hits_per_day', 757)
# 29 ('day_unique_s_count', 756)
# 30 ('weekday', 682)
# 31 ('var_hits_per_hour', 677)
# 32 ('geoNetwork_metro', 667)
# 33 ('geoNetwork_country', 601)
# 34 ('weekday_unique_user_count', 587)
# 35 ('geoNetwork_region', 557)
# 36 ('trafficSource_source', 533)
# 37 ('medium_hits_mean', 506)
# 38 ('mean_hits_per_network_domain', 494)
# 39 ('totals_newVisits', 466)
# 40 ('month_unique_s_count', 395)
# 41 ('count_pageviews_per_network_domain', 387)
# 42 ('hour_unique_s_count', 363)
# 43 ('device_operatingSystem', 313)
# 44 ('browser_category', 266)
# 45 ('medium_hits_sum', 257)
# 46 ('device_deviceCategory', 255)
# 47 ('geoNetwork_subContinent', 148)
# 48 ('channelGrouping', 137)
# 49 ('device_isMobile', 122)
# 50 ('sum_hits_per_network_domain', 110)
# 51 ('weekday_unique_s_count', 102)
# 52 ('weekofmonth', 92)
# 53 ('trafficSource_keyword', 87)
# 54 ('totals_bounces', 64)
# 55 ('count_hits_per_network_domain', 44)
# 56 ('campaign_medium', 44)
# 57 ('geoNetwork_continent', 19)
# 58 ('trafficSource_medium', 17)
# 59 ('medium_hits_max', 15)
# 60 ('device_browser', 7)
# 61 ('min_hits_per_day', 0)
# 62 ('min_hits_per_hour', 0)
# 63 ('medium_hits_min', 0)
# raw_train: results/2018-09-26T225219__T1.513_V1.310_K/reg_train_2018-09-26T225219.csv
# raw_test: results/2018-09-26T225219__T1.513_V1.310_K/reg_test_2018-09-26T225219.csv
# submit: results/2018-09-26T225219__T1.513_V1.310_K/aiden_2018-09-26T225219.csv.tar.gz
# cp -f reg_lgbm.ipynb results/2018-09-26T225219__T1.513_V1.310_K/reg_lgbm.ipynb
#
# results/2018-09-26T225219__T1.513_V1.310_K/aiden_2018-09-26T225219.csv.tar.gz
# Fold: GroupKFold_01
# Training until validation scores don't improve for 100 rounds.
# [25]	train's rmse: 1.8959	valid's rmse: 1.57859
# [50]	train's rmse: 1.79641	valid's rmse: 1.50801
# [75]	train's rmse: 1.7246	valid's rmse: 1.46213
# [100]	train's rmse: 1.67442	valid's rmse: 1.43302
# [125]	train's rmse: 1.63712	valid's rmse: 1.41507
# [150]	train's rmse: 1.60798	valid's rmse: 1.40252
# [175]	train's rmse: 1.58526	valid's rmse: 1.39475
# [200]	train's rmse: 1.56713	valid's rmse: 1.38916
# [225]	train's rmse: 1.5524	valid's rmse: 1.38558
# [250]	train's rmse: 1.53936	valid's rmse: 1.38341
# [275]	train's rmse: 1.52789	valid's rmse: 1.3819
# [300]	train's rmse: 1.51814	valid's rmse: 1.38121
# [325]	train's rmse: 1.50988	valid's rmse: 1.38014
# [350]	train's rmse: 1.50227	valid's rmse: 1.37961
# [375]	train's rmse: 1.4959	valid's rmse: 1.37902
# [400]	train's rmse: 1.49074	valid's rmse: 1.37826
# [425]	train's rmse: 1.48628	valid's rmse: 1.37782
# [450]	train's rmse: 1.48244	valid's rmse: 1.37749
# [475]	train's rmse: 1.479	valid's rmse: 1.37704
# [500]	train's rmse: 1.47725	valid's rmse: 1.37682
# Did not meet early stopping. Best iteration is:
# [500]	train's rmse: 1.47725	valid's rmse: 1.37682
# predict train set
# predict test set
# <feature_importance>
# 0 ('totals_pageviews_hit_rate', 8326)
# 1 ('totals_pageviews', 7043)
# 2 ('totals_hits', 4682)
# 3 ('visitNumber', 4629)
# 4 ('weekofyear', 4398)
# 5 ('geoNetwork_city', 4119)
# 6 ('geoNetwork_networkDomain', 3366)
# 7 ('source_country', 3031)
# 8 ('user_hour_mean', 2562)
# 9 ('user_hour_max', 1874)
# 10 ('browser_operatingSystem', 1866)
# 11 ('user_hour_min', 1685)
# 12 ('hour_unique_user_count', 1675)
# 13 ('month', 1646)
# 14 ('mean_hits_per_day', 1632)
# 15 ('month_unique_user_count', 1541)
# 16 ('day', 1483)
# 17 ('var_hits_per_day', 1452)
# 18 ('max_hits_per_day', 1363)
# 19 ('mean_hour_per_browser_operatingSystem', 1330)
# 20 ('day_unique_user_count', 1315)
# 21 ('mean_pageviews_per_network_domain', 1280)
# 22 ('max_hits_per_hour', 1197)
# 23 ('hour', 1170)
# 24 ('sum_hits_per_hour', 1130)
# 25 ('sum_pageviews_per_network_domain', 1119)
# 26 ('mean_hits_per_hour', 1076)
# 27 ('sum_hits_per_day', 957)
# 28 ('trafficSource_isTrueDirect', 910)
# 29 ('day_unique_s_count', 891)
# 30 ('weekday', 869)
# 31 ('geoNetwork_metro', 857)
# 32 ('var_hits_per_hour', 836)
# 33 ('geoNetwork_region', 700)
# 34 ('weekday_unique_user_count', 670)
# 35 ('geoNetwork_country', 630)
# 36 ('medium_hits_mean', 618)
# 37 ('mean_hits_per_network_domain', 614)
# 38 ('trafficSource_source', 559)
# 39 ('month_unique_s_count', 537)
# 40 ('totals_newVisits', 530)
# 41 ('count_pageviews_per_network_domain', 448)
# 42 ('hour_unique_s_count', 439)
# 43 ('browser_category', 374)
# 44 ('device_operatingSystem', 330)
# 45 ('medium_hits_sum', 329)
# 46 ('device_deviceCategory', 236)
# 47 ('sum_hits_per_network_domain', 163)
# 48 ('geoNetwork_subContinent', 159)
# 49 ('totals_bounces', 153)
# 50 ('channelGrouping', 139)
# 51 ('device_isMobile', 126)
# 52 ('weekday_unique_s_count', 119)
# 53 ('weekofmonth', 117)
# 54 ('trafficSource_keyword', 76)
# 55 ('count_hits_per_network_domain', 55)
# 56 ('campaign_medium', 44)
# 57 ('medium_hits_max', 26)
# 58 ('geoNetwork_continent', 21)
# 59 ('trafficSource_medium', 13)
# 60 ('device_browser', 9)
# 61 ('min_hits_per_day', 0)
# 62 ('min_hits_per_hour', 0)
# 63 ('medium_hits_min', 0)
# raw_train: results/2018-09-26T225338__T1.477_V1.377_K/reg_train_2018-09-26T225338.csv
# raw_test: results/2018-09-26T225338__T1.477_V1.377_K/reg_test_2018-09-26T225338.csv
# submit: results/2018-09-26T225338__T1.477_V1.377_K/aiden_2018-09-26T225338.csv.tar.gz
# cp -f reg_lgbm.ipynb results/2018-09-26T225338__T1.477_V1.377_K/reg_lgbm.ipynb
#
# results/2018-09-26T225338__T1.477_V1.377_K/aiden_2018-09-26T225338.csv.tar.gz
# Fold: GroupKFold_02
# Training until validation scores don't improve for 100 rounds.
# [25]	train's rmse: 1.83292	valid's rmse: 2.1954
# [50]	train's rmse: 1.73796	valid's rmse: 2.09705
# [75]	train's rmse: 1.66913	valid's rmse: 2.02703
# [100]	train's rmse: 1.62083	valid's rmse: 1.9773
# [125]	train's rmse: 1.58496	valid's rmse: 1.94404
# [150]	train's rmse: 1.55651	valid's rmse: 1.91977
# [175]	train's rmse: 1.53441	valid's rmse: 1.90236
# [200]	train's rmse: 1.51659	valid's rmse: 1.88891
# [225]	train's rmse: 1.50207	valid's rmse: 1.87928
# [250]	train's rmse: 1.48916	valid's rmse: 1.87266
# [275]	train's rmse: 1.47767	valid's rmse: 1.86721
# [300]	train's rmse: 1.46911	valid's rmse: 1.86324
# [325]	train's rmse: 1.46188	valid's rmse: 1.8607
# [350]	train's rmse: 1.45508	valid's rmse: 1.85883
# [375]	train's rmse: 1.44898	valid's rmse: 1.85731
# [400]	train's rmse: 1.4439	valid's rmse: 1.85609
# [425]	train's rmse: 1.43969	valid's rmse: 1.85551
# [450]	train's rmse: 1.43574	valid's rmse: 1.85485
# [475]	train's rmse: 1.43299	valid's rmse: 1.8544
# [500]	train's rmse: 1.43085	valid's rmse: 1.85393
# Did not meet early stopping. Best iteration is:
# [500]	train's rmse: 1.43085	valid's rmse: 1.85393
# predict train set
# predict test set
# <feature_importance>
# 0 ('totals_pageviews_hit_rate', 8242)
# 1 ('totals_pageviews', 7170)
# 2 ('totals_hits', 4627)
# 3 ('visitNumber', 4553)
# 4 ('weekofyear', 4245)
# 5 ('geoNetwork_city', 4198)
# 6 ('geoNetwork_networkDomain', 3299)
# 7 ('source_country', 2962)
# 8 ('user_hour_mean', 2558)
# 9 ('user_hour_max', 1947)
# 10 ('browser_operatingSystem', 1783)
# 11 ('user_hour_min', 1626)
# 12 ('month', 1620)
# 13 ('day', 1610)
# 14 ('hour_unique_user_count', 1549)
# 15 ('mean_hits_per_day', 1457)
# 16 ('var_hits_per_day', 1356)
# 17 ('day_unique_user_count', 1306)
# 18 ('max_hits_per_day', 1300)
# 19 ('max_hits_per_hour', 1280)
# 20 ('mean_hour_per_browser_operatingSystem', 1278)
# 21 ('month_unique_user_count', 1191)
# 22 ('mean_hits_per_hour', 1113)
# 23 ('mean_pageviews_per_network_domain', 1106)
# 24 ('sum_pageviews_per_network_domain', 1095)
# 25 ('hour', 1084)
# 26 ('trafficSource_isTrueDirect', 1012)
# 27 ('sum_hits_per_hour', 1006)
# 28 ('sum_hits_per_day', 954)
# 29 ('weekday', 871)
# 30 ('day_unique_s_count', 860)
# 31 ('var_hits_per_hour', 857)
# 32 ('geoNetwork_metro', 840)
# 33 ('weekday_unique_user_count', 772)
# 34 ('geoNetwork_region', 719)
# 35 ('medium_hits_mean', 649)
# 36 ('geoNetwork_country', 602)
# 37 ('trafficSource_source', 582)
# 38 ('mean_hits_per_network_domain', 524)
# 39 ('totals_newVisits', 476)
# 40 ('count_pageviews_per_network_domain', 475)
# 41 ('hour_unique_s_count', 407)
# 42 ('device_operatingSystem', 394)
# 43 ('month_unique_s_count', 392)
# 44 ('medium_hits_sum', 335)
# 45 ('browser_category', 305)
# 46 ('device_deviceCategory', 301)
# 47 ('sum_hits_per_network_domain', 186)
# 48 ('totals_bounces', 174)
# 49 ('geoNetwork_subContinent', 145)
# 50 ('device_isMobile', 140)
# 51 ('weekday_unique_s_count', 130)
# 52 ('channelGrouping', 106)
# 53 ('weekofmonth', 101)
# 54 ('trafficSource_keyword', 79)
# 55 ('campaign_medium', 59)
# 56 ('count_hits_per_network_domain', 46)
# 57 ('geoNetwork_continent', 24)
# 58 ('trafficSource_medium', 24)
# 59 ('medium_hits_max', 18)
# 60 ('device_browser', 16)
# 61 ('min_hits_per_day', 0)
# 62 ('min_hits_per_hour', 0)
# 63 ('medium_hits_min', 0)
# raw_train: results/2018-09-26T225500__T1.431_V1.854_K/reg_train_2018-09-26T225500.csv
# raw_test: results/2018-09-26T225500__T1.431_V1.854_K/reg_test_2018-09-26T225500.csv
# submit: results/2018-09-26T225500__T1.431_V1.854_K/aiden_2018-09-26T225500.csv.tar.gz
# cp -f reg_lgbm.ipynb results/2018-09-26T225500__T1.431_V1.854_K/reg_lgbm.ipynb
#
# results/2018-09-26T225500__T1.431_V1.854_K/aiden_2018-09-26T225500.csv.tar.gz
# Fold: GroupKFold_03
# Training until validation scores don't improve for 100 rounds.
# [25]	train's rmse: 1.84542	valid's rmse: 2.05024
# [50]	train's rmse: 1.74769	valid's rmse: 1.96289
# [75]	train's rmse: 1.67739	valid's rmse: 1.90998
# [100]	train's rmse: 1.62787	valid's rmse: 1.88052
# [125]	train's rmse: 1.59134	valid's rmse: 1.86429
# [150]	train's rmse: 1.56269	valid's rmse: 1.85462
# [175]	train's rmse: 1.54077	valid's rmse: 1.85039
# [200]	train's rmse: 1.52293	valid's rmse: 1.84862
# [225]	train's rmse: 1.50865	valid's rmse: 1.84772
# [250]	train's rmse: 1.49616	valid's rmse: 1.84845
# [275]	train's rmse: 1.48527	valid's rmse: 1.84974
# [300]	train's rmse: 1.4758	valid's rmse: 1.85067
# Early stopping, best iteration is:
# [221]	train's rmse: 1.51074	valid's rmse: 1.84768
# predict train set
# predict test set
# <feature_importance>
# 0 ('totals_pageviews_hit_rate', 5051)
# 1 ('totals_pageviews', 3543)
# 2 ('visitNumber', 3006)
# 3 ('weekofyear', 2875)
# 4 ('geoNetwork_city', 2552)
# 5 ('totals_hits', 2467)
# 6 ('source_country', 2050)
# 7 ('geoNetwork_networkDomain', 1564)
# 8 ('user_hour_mean', 1350)
# 9 ('browser_operatingSystem', 1207)
# 10 ('user_hour_min', 1076)
# 11 ('hour_unique_user_count', 979)
# 12 ('month', 957)
# 13 ('user_hour_max', 952)
# 14 ('mean_hour_per_browser_operatingSystem', 840)
# 15 ('mean_hits_per_day', 832)
# 16 ('month_unique_user_count', 795)
# 17 ('var_hits_per_day', 748)
# 18 ('max_hits_per_day', 719)
# 19 ('day', 695)
# 20 ('sum_hits_per_hour', 669)
# 21 ('day_unique_user_count', 653)
# 22 ('hour', 621)
# 23 ('trafficSource_isTrueDirect', 620)
# 24 ('mean_hits_per_hour', 599)
# 25 ('max_hits_per_hour', 585)
# 26 ('mean_pageviews_per_network_domain', 571)
# 27 ('geoNetwork_metro', 566)
# 28 ('sum_hits_per_day', 560)
# 29 ('sum_pageviews_per_network_domain', 553)
# 30 ('geoNetwork_country', 518)
# 31 ('day_unique_s_count', 476)
# 32 ('var_hits_per_hour', 469)
# 33 ('trafficSource_source', 457)
# 34 ('medium_hits_mean', 416)
# 35 ('weekday', 410)
# 36 ('geoNetwork_region', 392)
# 37 ('totals_newVisits', 388)
# 38 ('weekday_unique_user_count', 326)
# 39 ('mean_hits_per_network_domain', 304)
# 40 ('hour_unique_s_count', 300)
# 41 ('month_unique_s_count', 256)
# 42 ('count_pageviews_per_network_domain', 241)
# 43 ('device_operatingSystem', 212)
# 44 ('browser_category', 206)
# 45 ('device_deviceCategory', 178)
# 46 ('medium_hits_sum', 154)
# 47 ('geoNetwork_subContinent', 133)
# 48 ('device_isMobile', 113)
# 49 ('sum_hits_per_network_domain', 87)
# 50 ('trafficSource_keyword', 81)
# 51 ('channelGrouping', 73)
# 52 ('weekday_unique_s_count', 59)
# 53 ('weekofmonth', 51)
# 54 ('totals_bounces', 45)
# 55 ('count_hits_per_network_domain', 21)
# 56 ('campaign_medium', 17)
# 57 ('geoNetwork_continent', 13)
# 58 ('medium_hits_max', 9)
# 59 ('trafficSource_medium', 7)
# 60 ('device_browser', 4)
# 61 ('min_hits_per_day', 0)
# 62 ('min_hits_per_hour', 0)
# 63 ('medium_hits_min', 0)
# raw_train: results/2018-09-26T225556__T1.511_V1.848_K/reg_train_2018-09-26T225556.csv
# raw_test: results/2018-09-26T225556__T1.511_V1.848_K/reg_test_2018-09-26T225556.csv
# submit: results/2018-09-26T225556__T1.511_V1.848_K/aiden_2018-09-26T225556.csv.tar.gz
# cp -f reg_lgbm.ipynb results/2018-09-26T225556__T1.511_V1.848_K/reg_lgbm.ipynb
#
# results/2018-09-26T225556__T1.511_V1.848_K/aiden_2018-09-26T225556.csv.tar.gz
# Fold: GroupKFold_04
# Training until validation scores don't improve for 100 rounds.
# [25]	train's rmse: 1.85645	valid's rmse: 1.98059
# [50]	train's rmse: 1.76	valid's rmse: 1.89241
# [75]	train's rmse: 1.69048	valid's rmse: 1.83194
# [100]	train's rmse: 1.64126	valid's rmse: 1.79123
# [125]	train's rmse: 1.60511	valid's rmse: 1.76222
# [150]	train's rmse: 1.57695	valid's rmse: 1.74154
# [175]	train's rmse: 1.55528	valid's rmse: 1.72592
# [200]	train's rmse: 1.5373	valid's rmse: 1.71508
# [225]	train's rmse: 1.52251	valid's rmse: 1.70675
# [250]	train's rmse: 1.51019	valid's rmse: 1.70111
# [275]	train's rmse: 1.4989	valid's rmse: 1.69606
# [300]	train's rmse: 1.48991	valid's rmse: 1.69287
# [325]	train's rmse: 1.48196	valid's rmse: 1.68998
# [350]	train's rmse: 1.47466	valid's rmse: 1.68775
# [375]	train's rmse: 1.46869	valid's rmse: 1.68641
# [400]	train's rmse: 1.46408	valid's rmse: 1.68518
# [425]	train's rmse: 1.45988	valid's rmse: 1.6846
# [450]	train's rmse: 1.4565	valid's rmse: 1.68417
# [475]	train's rmse: 1.45366	valid's rmse: 1.68395
# [500]	train's rmse: 1.45145	valid's rmse: 1.68368
# Did not meet early stopping. Best iteration is:
# [500]	train's rmse: 1.45145	valid's rmse: 1.68368
# predict train set
# predict test set
# <feature_importance>
# 0 ('totals_pageviews_hit_rate', 8560)
# 1 ('totals_pageviews', 7261)
# 2 ('totals_hits', 4690)
# 3 ('visitNumber', 4558)
# 4 ('weekofyear', 4477)
# 5 ('geoNetwork_city', 4115)
# 6 ('geoNetwork_networkDomain', 3365)
# 7 ('source_country', 2975)
# 8 ('user_hour_mean', 2389)
# 9 ('browser_operatingSystem', 1920)
# 10 ('month_unique_user_count', 1910)
# 11 ('user_hour_max', 1853)
# 12 ('hour_unique_user_count', 1705)
# 13 ('user_hour_min', 1650)
# 14 ('day', 1473)
# 15 ('var_hits_per_day', 1423)
# 16 ('max_hits_per_day', 1374)
# 17 ('mean_hits_per_day', 1366)
# 18 ('day_unique_user_count', 1310)
# 19 ('month', 1290)
# 20 ('mean_hour_per_browser_operatingSystem', 1228)
# 21 ('sum_hits_per_hour', 1087)
# 22 ('max_hits_per_hour', 1087)
# 23 ('sum_pageviews_per_network_domain', 1086)
# 24 ('mean_pageviews_per_network_domain', 1085)
# 25 ('trafficSource_isTrueDirect', 1053)
# 26 ('mean_hits_per_hour', 1048)
# 27 ('hour', 1030)
# 28 ('day_unique_s_count', 926)
# 29 ('sum_hits_per_day', 892)
# 30 ('weekday', 848)
# 31 ('geoNetwork_metro', 748)
# 32 ('var_hits_per_hour', 713)
# 33 ('weekday_unique_user_count', 670)
# 34 ('geoNetwork_country', 664)
# 35 ('geoNetwork_region', 630)
# 36 ('mean_hits_per_network_domain', 617)
# 37 ('medium_hits_mean', 588)
# 38 ('trafficSource_source', 569)
# 39 ('totals_newVisits', 512)
# 40 ('count_pageviews_per_network_domain', 483)
# 41 ('hour_unique_s_count', 409)
# 42 ('month_unique_s_count', 384)
# 43 ('browser_category', 341)
# 44 ('device_operatingSystem', 306)
# 45 ('medium_hits_sum', 306)
# 46 ('device_deviceCategory', 250)
# 47 ('totals_bounces', 162)
# 48 ('sum_hits_per_network_domain', 158)
# 49 ('geoNetwork_subContinent', 152)
# 50 ('weekofmonth', 121)
# 51 ('device_isMobile', 120)
# 52 ('channelGrouping', 110)
# 53 ('weekday_unique_s_count', 94)
# 54 ('trafficSource_keyword', 77)
# 55 ('count_hits_per_network_domain', 55)
# 56 ('campaign_medium', 37)
# 57 ('device_browser', 21)
# 58 ('medium_hits_max', 20)
# 59 ('trafficSource_medium', 12)
# 60 ('geoNetwork_continent', 10)
# 61 ('min_hits_per_day', 0)
# 62 ('min_hits_per_hour', 0)
# 63 ('medium_hits_min', 0)
# raw_train: results/2018-09-26T225716__T1.451_V1.684_K/reg_train_2018-09-26T225716.csv
# raw_test: results/2018-09-26T225716__T1.451_V1.684_K/reg_test_2018-09-26T225716.csv
# submit: results/2018-09-26T225716__T1.451_V1.684_K/aiden_2018-09-26T225716.csv.tar.gz
# cp -f reg_lgbm.ipynb results/2018-09-26T225716__T1.451_V1.684_K/reg_lgbm.ipynb
#
# results/2018-09-26T225716__T1.451_V1.684_K/aiden_2018-09-26T225716.csv.tar.gz
# Fold: GroupKFold_05
# Training until validation scores don't improve for 100 rounds.
# [25]	train's rmse: 1.86417	valid's rmse: 1.83767
# [50]	train's rmse: 1.76471	valid's rmse: 1.76154
# [75]	train's rmse: 1.69348	valid's rmse: 1.71731
# [100]	train's rmse: 1.64337	valid's rmse: 1.69493
# [125]	train's rmse: 1.60691	valid's rmse: 1.68481
# [150]	train's rmse: 1.57815	valid's rmse: 1.68172
# [175]	train's rmse: 1.55542	valid's rmse: 1.68225
# [200]	train's rmse: 1.5371	valid's rmse: 1.68408
# [225]	train's rmse: 1.52272	valid's rmse: 1.68681
# Early stopping, best iteration is:
# [148]	train's rmse: 1.5801	valid's rmse: 1.68169
# predict train set
# predict test set
# <feature_importance>
# 0 ('totals_pageviews_hit_rate', 3654)
# 1 ('totals_pageviews', 2677)
# 2 ('visitNumber', 2101)
# 3 ('totals_hits', 1808)
# 4 ('geoNetwork_city', 1745)
# 5 ('weekofyear', 1685)
# 6 ('source_country', 1407)
# 7 ('geoNetwork_networkDomain', 1007)
# 8 ('month_unique_user_count', 915)
# 9 ('browser_operatingSystem', 828)
# 10 ('user_hour_mean', 817)
# 11 ('hour_unique_user_count', 797)
# 12 ('user_hour_min', 647)
# 13 ('mean_hour_per_browser_operatingSystem', 572)
# 14 ('user_hour_max', 564)
# 15 ('mean_hits_per_day', 538)
# 16 ('day_unique_user_count', 501)
# 17 ('month', 482)
# 18 ('var_hits_per_day', 479)
# 19 ('day', 470)
# 20 ('max_hits_per_hour', 448)
# 21 ('geoNetwork_metro', 447)
# 22 ('trafficSource_isTrueDirect', 433)
# 23 ('sum_hits_per_hour', 422)
# 24 ('geoNetwork_country', 401)
# 25 ('hour', 401)
# 26 ('max_hits_per_day', 386)
# 27 ('sum_pageviews_per_network_domain', 373)
# 28 ('mean_pageviews_per_network_domain', 370)
# 29 ('mean_hits_per_hour', 336)
# 30 ('totals_newVisits', 328)
# 31 ('geoNetwork_region', 327)
# 32 ('sum_hits_per_day', 323)
# 33 ('trafficSource_source', 315)
# 34 ('day_unique_s_count', 297)
# 35 ('weekday', 292)
# 36 ('var_hits_per_hour', 287)
# 37 ('weekday_unique_user_count', 217)
# 38 ('medium_hits_mean', 217)
# 39 ('hour_unique_s_count', 214)
# 40 ('mean_hits_per_network_domain', 194)
# 41 ('count_pageviews_per_network_domain', 176)
# 42 ('browser_category', 165)
# 43 ('device_operatingSystem', 157)
# 44 ('device_deviceCategory', 155)
# 45 ('month_unique_s_count', 119)
# 46 ('geoNetwork_subContinent', 113)
# 47 ('device_isMobile', 98)
# 48 ('medium_hits_sum', 92)
# 49 ('sum_hits_per_network_domain', 57)
# 50 ('channelGrouping', 51)
# 51 ('weekday_unique_s_count', 50)
# 52 ('weekofmonth', 43)
# 53 ('trafficSource_keyword', 34)
# 54 ('totals_bounces', 31)
# 55 ('campaign_medium', 31)
# 56 ('count_hits_per_network_domain', 19)
# 57 ('geoNetwork_continent', 12)
# 58 ('device_browser', 6)
# 59 ('trafficSource_medium', 6)
# 60 ('medium_hits_max', 3)
# 61 ('min_hits_per_day', 0)
# 62 ('min_hits_per_hour', 0)
# 63 ('medium_hits_min', 0)
# raw_train: results/2018-09-26T225804__T1.580_V1.682_K/reg_train_2018-09-26T225804.csv
# raw_test: results/2018-09-26T225804__T1.580_V1.682_K/reg_test_2018-09-26T225804.csv
# submit: results/2018-09-26T225804__T1.580_V1.682_K/aiden_2018-09-26T225804.csv.tar.gz
# cp -f reg_lgbm.ipynb results/2018-09-26T225804__T1.580_V1.682_K/reg_lgbm.ipynb
#
# results/2018-09-26T225804__T1.580_V1.682_K/aiden_2018-09-26T225804.csv.tar.gz
# Fold: GroupKFold_06
# Training until validation scores don't improve for 100 rounds.
# [25]	train's rmse: 1.86542	valid's rmse: 1.86129
# [50]	train's rmse: 1.76907	valid's rmse: 1.76666
# [75]	train's rmse: 1.69949	valid's rmse: 1.70014
# [100]	train's rmse: 1.65053	valid's rmse: 1.65535
# [125]	train's rmse: 1.61454	valid's rmse: 1.62523
# [150]	train's rmse: 1.58615	valid's rmse: 1.60405
# [175]	train's rmse: 1.56424	valid's rmse: 1.59
# [200]	train's rmse: 1.54653	valid's rmse: 1.57945
# [225]	train's rmse: 1.53196	valid's rmse: 1.57242
# [250]	train's rmse: 1.51913	valid's rmse: 1.56798
# [275]	train's rmse: 1.50801	valid's rmse: 1.56473
# [300]	train's rmse: 1.49889	valid's rmse: 1.56288
# [325]	train's rmse: 1.49104	valid's rmse: 1.56106
# [350]	train's rmse: 1.48423	valid's rmse: 1.56013
# [375]	train's rmse: 1.47813	valid's rmse: 1.55975
# [400]	train's rmse: 1.47313	valid's rmse: 1.55905
# [425]	train's rmse: 1.46909	valid's rmse: 1.55888
# [450]	train's rmse: 1.46526	valid's rmse: 1.5587
# [475]	train's rmse: 1.46181	valid's rmse: 1.55873
# [500]	train's rmse: 1.45906	valid's rmse: 1.55879
# Did not meet early stopping. Best iteration is:
# [500]	train's rmse: 1.45906	valid's rmse: 1.55879
# predict train set
# predict test set
# <feature_importance>
# 0 ('totals_pageviews_hit_rate', 8443)
# 1 ('totals_pageviews', 7173)
# 2 ('totals_hits', 4548)
# 3 ('visitNumber', 4411)
# 4 ('weekofyear', 4356)
# 5 ('geoNetwork_city', 4304)
# 6 ('geoNetwork_networkDomain', 3366)
# 7 ('source_country', 2987)
# 8 ('user_hour_mean', 2406)
# 9 ('user_hour_max', 1907)
# 10 ('browser_operatingSystem', 1758)
# 11 ('month', 1752)
# 12 ('hour_unique_user_count', 1729)
# 13 ('user_hour_min', 1670)
# 14 ('mean_hits_per_day', 1590)
# 15 ('var_hits_per_day', 1549)
# 16 ('month_unique_user_count', 1512)
# 17 ('day', 1433)
# 18 ('max_hits_per_day', 1329)
# 19 ('day_unique_user_count', 1322)
# 20 ('max_hits_per_hour', 1282)
# 21 ('mean_hour_per_browser_operatingSystem', 1250)
# 22 ('mean_pageviews_per_network_domain', 1177)
# 23 ('sum_hits_per_hour', 1125)
# 24 ('hour', 1075)
# 25 ('sum_pageviews_per_network_domain', 1046)
# 26 ('mean_hits_per_hour', 1043)
# 27 ('sum_hits_per_day', 975)
# 28 ('trafficSource_isTrueDirect', 969)
# 29 ('day_unique_s_count', 890)
# 30 ('weekday', 807)
# 31 ('geoNetwork_metro', 760)
# 32 ('var_hits_per_hour', 749)
# 33 ('weekday_unique_user_count', 692)
# 34 ('geoNetwork_region', 670)
# 35 ('geoNetwork_country', 663)
# 36 ('trafficSource_source', 596)
# 37 ('medium_hits_mean', 576)
# 38 ('mean_hits_per_network_domain', 574)
# 39 ('count_pageviews_per_network_domain', 533)
# 40 ('month_unique_s_count', 520)
# 41 ('totals_newVisits', 504)
# 42 ('hour_unique_s_count', 483)
# 43 ('browser_category', 315)
# 44 ('device_operatingSystem', 309)
# 45 ('medium_hits_sum', 277)
# 46 ('device_deviceCategory', 272)
# 47 ('totals_bounces', 175)
# 48 ('geoNetwork_subContinent', 170)
# 49 ('sum_hits_per_network_domain', 146)
# 50 ('device_isMobile', 129)
# 51 ('channelGrouping', 123)
# 52 ('weekday_unique_s_count', 122)
# 53 ('trafficSource_keyword', 121)
# 54 ('weekofmonth', 99)
# 55 ('campaign_medium', 55)
# 56 ('count_hits_per_network_domain', 51)
# 57 ('geoNetwork_continent', 28)
# 58 ('device_browser', 21)
# 59 ('medium_hits_max', 20)
# 60 ('trafficSource_medium', 16)
# 61 ('min_hits_per_day', 0)
# 62 ('min_hits_per_hour', 0)
# 63 ('medium_hits_min', 0)
# raw_train: results/2018-09-26T225923__T1.459_V1.559_K/reg_train_2018-09-26T225923.csv
# raw_test: results/2018-09-26T225923__T1.459_V1.559_K/reg_test_2018-09-26T225923.csv
# submit: results/2018-09-26T225923__T1.459_V1.559_K/aiden_2018-09-26T225923.csv.tar.gz
# cp -f reg_lgbm.ipynb results/2018-09-26T225923__T1.459_V1.559_K/reg_lgbm.ipynb
#
# results/2018-09-26T225923__T1.459_V1.559_K/aiden_2018-09-26T225923.csv.tar.gz
# Fold: GroupKFold_07
# Training until validation scores don't improve for 100 rounds.
# [25]	train's rmse: 1.85899	valid's rmse: 1.95906
# [50]	train's rmse: 1.76261	valid's rmse: 1.86859
# [75]	train's rmse: 1.69305	valid's rmse: 1.80244
# [100]	train's rmse: 1.64418	valid's rmse: 1.75804
# [125]	train's rmse: 1.60808	valid's rmse: 1.72652
# [150]	train's rmse: 1.57952	valid's rmse: 1.70229
# [175]	train's rmse: 1.55774	valid's rmse: 1.68583
# [200]	train's rmse: 1.54014	valid's rmse: 1.67344
# [225]	train's rmse: 1.52538	valid's rmse: 1.66467
# [250]	train's rmse: 1.51233	valid's rmse: 1.65818
# [275]	train's rmse: 1.50086	valid's rmse: 1.65322
# [300]	train's rmse: 1.49202	valid's rmse: 1.64975
# [325]	train's rmse: 1.48413	valid's rmse: 1.6468
# [350]	train's rmse: 1.47711	valid's rmse: 1.64526
# [375]	train's rmse: 1.47108	valid's rmse: 1.64379
# [400]	train's rmse: 1.46603	valid's rmse: 1.64286
# [425]	train's rmse: 1.4617	valid's rmse: 1.64213
# [450]	train's rmse: 1.4583	valid's rmse: 1.64178
# [475]	train's rmse: 1.45527	valid's rmse: 1.64123
# [500]	train's rmse: 1.45357	valid's rmse: 1.641
# Did not meet early stopping. Best iteration is:
# [500]	train's rmse: 1.45357	valid's rmse: 1.641
# predict train set
# predict test set
# <feature_importance>
# 0 ('totals_pageviews_hit_rate', 8349)
# 1 ('totals_pageviews', 7217)
# 2 ('totals_hits', 4588)
# 3 ('visitNumber', 4539)
# 4 ('geoNetwork_city', 4253)
# 5 ('weekofyear', 3995)
# 6 ('geoNetwork_networkDomain', 3327)
# 7 ('source_country', 2973)
# 8 ('user_hour_mean', 2466)
# 9 ('user_hour_max', 1838)
# 10 ('browser_operatingSystem', 1837)
# 11 ('hour_unique_user_count', 1705)
# 12 ('user_hour_min', 1692)
# 13 ('mean_hits_per_day', 1636)
# 14 ('month_unique_user_count', 1628)
# 15 ('var_hits_per_day', 1504)
# 16 ('day', 1465)
# 17 ('month', 1459)
# 18 ('max_hits_per_day', 1342)
# 19 ('max_hits_per_hour', 1246)
# 20 ('mean_hour_per_browser_operatingSystem', 1194)
# 21 ('day_unique_user_count', 1164)
# 22 ('hour', 1123)
# 23 ('mean_pageviews_per_network_domain', 1107)
# 24 ('sum_hits_per_hour', 1054)
# 25 ('sum_pageviews_per_network_domain', 1041)
# 26 ('sum_hits_per_day', 1039)
# 27 ('trafficSource_isTrueDirect', 1021)
# 28 ('mean_hits_per_hour', 975)
# 29 ('weekday', 925)
# 30 ('day_unique_s_count', 869)
# 31 ('geoNetwork_metro', 850)
# 32 ('var_hits_per_hour', 818)
# 33 ('weekday_unique_user_count', 736)
# 34 ('geoNetwork_region', 614)
# 35 ('geoNetwork_country', 613)
# 36 ('trafficSource_source', 605)
# 37 ('medium_hits_mean', 585)
# 38 ('mean_hits_per_network_domain', 537)
# 39 ('month_unique_s_count', 534)
# 40 ('totals_newVisits', 498)
# 41 ('count_pageviews_per_network_domain', 471)
# 42 ('hour_unique_s_count', 430)
# 43 ('device_operatingSystem', 309)
# 44 ('medium_hits_sum', 307)
# 45 ('device_deviceCategory', 284)
# 46 ('browser_category', 284)
# 47 ('sum_hits_per_network_domain', 155)
# 48 ('totals_bounces', 152)
# 49 ('weekday_unique_s_count', 127)
# 50 ('device_isMobile', 124)
# 51 ('channelGrouping', 120)
# 52 ('geoNetwork_subContinent', 118)
# 53 ('weekofmonth', 118)
# 54 ('trafficSource_keyword', 75)
# 55 ('count_hits_per_network_domain', 49)
# 56 ('campaign_medium', 39)
# 57 ('geoNetwork_continent', 29)
# 58 ('medium_hits_max', 26)
# 59 ('trafficSource_medium', 21)
# 60 ('device_browser', 15)
# 61 ('min_hits_per_day', 0)
# 62 ('min_hits_per_hour', 0)
# 63 ('medium_hits_min', 0)
# raw_train: results/2018-09-26T230041__T1.454_V1.641_K/reg_train_2018-09-26T230041.csv
# raw_test: results/2018-09-26T230041__T1.454_V1.641_K/reg_test_2018-09-26T230041.csv
# submit: results/2018-09-26T230041__T1.454_V1.641_K/aiden_2018-09-26T230041.csv.tar.gz
# cp -f reg_lgbm.ipynb results/2018-09-26T230041__T1.454_V1.641_K/reg_lgbm.ipynb
#
# results/2018-09-26T230041__T1.454_V1.641_K/aiden_2018-09-26T230041.csv.tar.gz
# Fold: GroupKFold_08
# Training until validation scores don't improve for 100 rounds.
# [25]	train's rmse: 1.84151	valid's rmse: 2.16548
# [50]	train's rmse: 1.74589	valid's rmse: 2.06609
# [75]	train's rmse: 1.67713	valid's rmse: 1.99385
# [100]	train's rmse: 1.6292	valid's rmse: 1.94486
# [125]	train's rmse: 1.59366	valid's rmse: 1.90753
# [150]	train's rmse: 1.56539	valid's rmse: 1.88002
# [175]	train's rmse: 1.5438	valid's rmse: 1.86129
# [200]	train's rmse: 1.52599	valid's rmse: 1.84797
# [225]	train's rmse: 1.51163	valid's rmse: 1.83755
# [250]	train's rmse: 1.49908	valid's rmse: 1.82991
# [275]	train's rmse: 1.48787	valid's rmse: 1.82421
# [300]	train's rmse: 1.47911	valid's rmse: 1.82029
# [325]	train's rmse: 1.47152	valid's rmse: 1.8169
# [350]	train's rmse: 1.4643	valid's rmse: 1.81391
# [375]	train's rmse: 1.45843	valid's rmse: 1.8122
# [400]	train's rmse: 1.45316	valid's rmse: 1.81112
# [425]	train's rmse: 1.44862	valid's rmse: 1.81069
# [450]	train's rmse: 1.44533	valid's rmse: 1.81069
# [475]	train's rmse: 1.44212	valid's rmse: 1.81055
# [500]	train's rmse: 1.43974	valid's rmse: 1.81027
# Did not meet early stopping. Best iteration is:
# [500]	train's rmse: 1.43974	valid's rmse: 1.81027
# predict train set
# predict test set
# <feature_importance>
# 0 ('totals_pageviews_hit_rate', 8696)
# 1 ('totals_pageviews', 7177)
# 2 ('totals_hits', 4672)
# 3 ('visitNumber', 4405)
# 4 ('weekofyear', 4203)
# 5 ('geoNetwork_city', 4195)
# 6 ('geoNetwork_networkDomain', 3380)
# 7 ('source_country', 2879)
# 8 ('user_hour_mean', 2590)
# 9 ('user_hour_max', 1900)
# 10 ('browser_operatingSystem', 1728)
# 11 ('user_hour_min', 1707)
# 12 ('hour_unique_user_count', 1632)
# 13 ('day', 1628)
# 14 ('mean_hits_per_day', 1613)
# 15 ('month', 1601)
# 16 ('var_hits_per_day', 1524)
# 17 ('day_unique_user_count', 1350)
# 18 ('max_hits_per_day', 1296)
# 19 ('month_unique_user_count', 1287)
# 20 ('mean_hour_per_browser_operatingSystem', 1241)
# 21 ('max_hits_per_hour', 1233)
# 22 ('mean_hits_per_hour', 1181)
# 23 ('mean_pageviews_per_network_domain', 1171)
# 24 ('hour', 1107)
# 25 ('sum_pageviews_per_network_domain', 1089)
# 26 ('sum_hits_per_hour', 1060)
# 27 ('sum_hits_per_day', 1002)
# 28 ('trafficSource_isTrueDirect', 940)
# 29 ('day_unique_s_count', 937)
# 30 ('weekday', 914)
# 31 ('var_hits_per_hour', 907)
# 32 ('geoNetwork_metro', 821)
# 33 ('weekday_unique_user_count', 689)
# 34 ('geoNetwork_region', 679)
# 35 ('mean_hits_per_network_domain', 637)
# 36 ('geoNetwork_country', 586)
# 37 ('medium_hits_mean', 570)
# 38 ('trafficSource_source', 513)
# 39 ('count_pageviews_per_network_domain', 499)
# 40 ('totals_newVisits', 489)
# 41 ('month_unique_s_count', 434)
# 42 ('hour_unique_s_count', 393)
# 43 ('device_operatingSystem', 354)
# 44 ('medium_hits_sum', 339)
# 45 ('browser_category', 268)
# 46 ('device_deviceCategory', 237)
# 47 ('sum_hits_per_network_domain', 158)
# 48 ('totals_bounces', 142)
# 49 ('geoNetwork_subContinent', 136)
# 50 ('weekday_unique_s_count', 127)
# 51 ('channelGrouping', 120)
# 52 ('weekofmonth', 119)
# 53 ('device_isMobile', 114)
# 54 ('trafficSource_keyword', 82)
# 55 ('campaign_medium', 59)
# 56 ('count_hits_per_network_domain', 56)
# 57 ('geoNetwork_continent', 28)
# 58 ('medium_hits_max', 22)
# 59 ('trafficSource_medium', 15)
# 60 ('device_browser', 9)
# 61 ('min_hits_per_day', 0)
# 62 ('min_hits_per_hour', 0)
# 63 ('medium_hits_min', 0)
# raw_train: results/2018-09-26T230201__T1.440_V1.810_K/reg_train_2018-09-26T230201.csv
# raw_test: results/2018-09-26T230201__T1.440_V1.810_K/reg_test_2018-09-26T230201.csv
# submit: results/2018-09-26T230201__T1.440_V1.810_K/aiden_2018-09-26T230201.csv.tar.gz
# cp -f reg_lgbm.ipynb results/2018-09-26T230201__T1.440_V1.810_K/reg_lgbm.ipynb
#
# results/2018-09-26T230201__T1.440_V1.810_K/aiden_2018-09-26T230201.csv.tar.gz
# Fold: GroupKFold_09
# Training until validation scores don't improve for 100 rounds.
# [25]	train's rmse: 1.87457	valid's rmse: 1.71327
# [50]	train's rmse: 1.77653	valid's rmse: 1.62955
# [75]	train's rmse: 1.70584	valid's rmse: 1.57703
# [100]	train's rmse: 1.65598	valid's rmse: 1.54511
# [125]	train's rmse: 1.6193	valid's rmse: 1.52698
# [150]	train's rmse: 1.59037	valid's rmse: 1.51646
# [175]	train's rmse: 1.56805	valid's rmse: 1.51093
# [200]	train's rmse: 1.54996	valid's rmse: 1.50876
# [225]	train's rmse: 1.53536	valid's rmse: 1.507
# [250]	train's rmse: 1.52234	valid's rmse: 1.50604
# [275]	train's rmse: 1.51116	valid's rmse: 1.5062
# [300]	train's rmse: 1.50214	valid's rmse: 1.50661
# [325]	train's rmse: 1.49439	valid's rmse: 1.50757
# [350]	train's rmse: 1.48694	valid's rmse: 1.50843
# Early stopping, best iteration is:
# [259]	train's rmse: 1.51796	valid's rmse: 1.50583
# predict train set
# predict test set
# <feature_importance>
# 0 ('totals_pageviews_hit_rate', 6175)
# 1 ('totals_pageviews', 4282)
# 2 ('visitNumber', 3342)
# 3 ('weekofyear', 3190)
# 4 ('geoNetwork_city', 2982)
# 5 ('totals_hits', 2822)
# 6 ('source_country', 2154)
# 7 ('geoNetwork_networkDomain', 1846)
# 8 ('user_hour_mean', 1562)
# 9 ('browser_operatingSystem', 1343)
# 10 ('hour_unique_user_count', 1197)
# 11 ('month', 1195)
# 12 ('user_hour_max', 1135)
# 13 ('user_hour_min', 1089)
# 14 ('mean_hits_per_day', 1020)
# 15 ('month_unique_user_count', 946)
# 16 ('mean_hour_per_browser_operatingSystem', 927)
# 17 ('day', 840)
# 18 ('max_hits_per_day', 824)
# 19 ('var_hits_per_day', 782)
# 20 ('day_unique_user_count', 772)
# 21 ('sum_hits_per_hour', 728)
# 22 ('trafficSource_isTrueDirect', 727)
# 23 ('mean_pageviews_per_network_domain', 706)
# 24 ('hour', 681)
# 25 ('max_hits_per_hour', 680)
# 26 ('sum_pageviews_per_network_domain', 657)
# 27 ('mean_hits_per_hour', 638)
# 28 ('sum_hits_per_day', 622)
# 29 ('geoNetwork_metro', 575)
# 30 ('geoNetwork_country', 574)
# 31 ('var_hits_per_hour', 533)
# 32 ('day_unique_s_count', 508)
# 33 ('geoNetwork_region', 471)
# 34 ('weekday', 469)
# 35 ('trafficSource_source', 465)
# 36 ('totals_newVisits', 445)
# 37 ('weekday_unique_user_count', 415)
# 38 ('medium_hits_mean', 379)
# 39 ('hour_unique_s_count', 361)
# 40 ('mean_hits_per_network_domain', 347)
# 41 ('count_pageviews_per_network_domain', 297)
# 42 ('device_operatingSystem', 248)
# 43 ('month_unique_s_count', 238)
# 44 ('browser_category', 231)
# 45 ('device_deviceCategory', 193)
# 46 ('medium_hits_sum', 176)
# 47 ('geoNetwork_subContinent', 148)
# 48 ('device_isMobile', 103)
# 49 ('sum_hits_per_network_domain', 101)
# 50 ('trafficSource_keyword', 81)
# 51 ('channelGrouping', 73)
# 52 ('weekday_unique_s_count', 72)
# 53 ('weekofmonth', 57)
# 54 ('totals_bounces', 49)
# 55 ('count_hits_per_network_domain', 35)
# 56 ('geoNetwork_continent', 18)
# 57 ('campaign_medium', 15)
# 58 ('device_browser', 9)
# 59 ('trafficSource_medium', 7)
# 60 ('medium_hits_max', 7)
# 61 ('min_hits_per_day', 0)
# 62 ('min_hits_per_hour', 0)
# 63 ('medium_hits_min', 0)
# raw_train: results/2018-09-26T230304__T1.518_V1.506_K/reg_train_2018-09-26T230304.csv
# raw_test: results/2018-09-26T230304__T1.518_V1.506_K/reg_test_2018-09-26T230304.csv
# submit: results/2018-09-26T230304__T1.518_V1.506_K/aiden_2018-09-26T230304.csv.tar.gz
# cp -f reg_lgbm.ipynb results/2018-09-26T230304__T1.518_V1.506_K/reg_lgbm.ipynb
#
# results/2018-09-26T230304__T1.518_V1.506_K/aiden_2018-09-26T230304.csv.tar.gz
# Fold: GroupKFold_10
# Training until validation scores don't improve for 100 rounds.
# [25]	train's rmse: 1.85409	valid's rmse: 2.01207
# [50]	train's rmse: 1.75795	valid's rmse: 1.91402
# [75]	train's rmse: 1.68867	valid's rmse: 1.84518
# [100]	train's rmse: 1.63954	valid's rmse: 1.79861
# [125]	train's rmse: 1.60341	valid's rmse: 1.76738
# [150]	train's rmse: 1.57509	valid's rmse: 1.74454
# [175]	train's rmse: 1.55332	valid's rmse: 1.72907
# [200]	train's rmse: 1.53588	valid's rmse: 1.71878
# [225]	train's rmse: 1.52137	valid's rmse: 1.71215
# [250]	train's rmse: 1.50864	valid's rmse: 1.70711
# [275]	train's rmse: 1.49725	valid's rmse: 1.70238
# [300]	train's rmse: 1.48829	valid's rmse: 1.69987
# [325]	train's rmse: 1.48075	valid's rmse: 1.69769
# [350]	train's rmse: 1.47359	valid's rmse: 1.69567
# [375]	train's rmse: 1.46768	valid's rmse: 1.69429
# [400]	train's rmse: 1.46252	valid's rmse: 1.69339
# [425]	train's rmse: 1.45778	valid's rmse: 1.69288
# [450]	train's rmse: 1.45414	valid's rmse: 1.69234
# [475]	train's rmse: 1.45131	valid's rmse: 1.69207
# [500]	train's rmse: 1.44936	valid's rmse: 1.69198
# Did not meet early stopping. Best iteration is:
# [500]	train's rmse: 1.44936	valid's rmse: 1.69198
# predict train set
# predict test set
# <feature_importance>
# 0 ('totals_pageviews_hit_rate', 8687)
# 1 ('totals_pageviews', 7082)
# 2 ('totals_hits', 4610)
# 3 ('visitNumber', 4513)
# 4 ('weekofyear', 4372)
# 5 ('geoNetwork_city', 4123)
# 6 ('geoNetwork_networkDomain', 3546)
# 7 ('source_country', 3040)
# 8 ('user_hour_mean', 2669)
# 9 ('user_hour_max', 1858)
# 10 ('user_hour_min', 1813)
# 11 ('browser_operatingSystem', 1745)
# 12 ('hour_unique_user_count', 1639)
# 13 ('month', 1601)
# 14 ('day', 1574)
# 15 ('mean_hits_per_day', 1538)
# 16 ('var_hits_per_day', 1510)
# 17 ('day_unique_user_count', 1299)
# 18 ('month_unique_user_count', 1274)
# 19 ('mean_hour_per_browser_operatingSystem', 1270)
# 20 ('max_hits_per_day', 1218)
# 21 ('max_hits_per_hour', 1165)
# 22 ('mean_pageviews_per_network_domain', 1100)
# 23 ('mean_hits_per_hour', 1085)
# 24 ('trafficSource_isTrueDirect', 1063)
# 25 ('hour', 1062)
# 26 ('sum_pageviews_per_network_domain', 1057)
# 27 ('sum_hits_per_hour', 978)
# 28 ('day_unique_s_count', 954)
# 29 ('sum_hits_per_day', 929)
# 30 ('weekday', 900)
# 31 ('geoNetwork_metro', 820)
# 32 ('var_hits_per_hour', 805)
# 33 ('weekday_unique_user_count', 756)
# 34 ('geoNetwork_region', 651)
# 35 ('geoNetwork_country', 625)
# 36 ('medium_hits_mean', 614)
# 37 ('trafficSource_source', 583)
# 38 ('mean_hits_per_network_domain', 535)
# 39 ('totals_newVisits', 501)
# 40 ('count_pageviews_per_network_domain', 468)
# 41 ('hour_unique_s_count', 424)
# 42 ('month_unique_s_count', 421)
# 43 ('browser_category', 337)
# 44 ('device_operatingSystem', 279)
# 45 ('medium_hits_sum', 275)
# 46 ('device_deviceCategory', 242)
# 47 ('sum_hits_per_network_domain', 172)
# 48 ('geoNetwork_subContinent', 151)
# 49 ('channelGrouping', 131)
# 50 ('totals_bounces', 131)
# 51 ('weekofmonth', 131)
# 52 ('weekday_unique_s_count', 122)
# 53 ('device_isMobile', 107)
# 54 ('trafficSource_keyword', 74)
# 55 ('count_hits_per_network_domain', 54)
# 56 ('campaign_medium', 47)
# 57 ('geoNetwork_continent', 27)
# 58 ('medium_hits_max', 23)
# 59 ('device_browser', 16)
# 60 ('trafficSource_medium', 14)
# 61 ('min_hits_per_day', 0)
# 62 ('min_hits_per_hour', 0)
# 63 ('medium_hits_min', 0)
# raw_train: results/2018-09-26T230424__T1.449_V1.692_K/reg_train_2018-09-26T230424.csv
# raw_test: results/2018-09-26T230424__T1.449_V1.692_K/reg_test_2018-09-26T230424.csv
# submit: results/2018-09-26T230424__T1.449_V1.692_K/aiden_2018-09-26T230424.csv.tar.gz
# cp -f reg_lgbm.ipynb results/2018-09-26T230424__T1.449_V1.692_K/reg_lgbm.ipynb
#
# results/2018-09-26T230424__T1.449_V1.692_K/aiden_2018-09-26T230424.csv.tar.gz
# Fold: GroupKFold_11
# Training until validation scores don't improve for 100 rounds.
# [25]	train's rmse: 1.87175	valid's rmse: 1.76225
# [50]	train's rmse: 1.77444	valid's rmse: 1.67438
# [75]	train's rmse: 1.70385	valid's rmse: 1.61549
# [100]	train's rmse: 1.65479	valid's rmse: 1.57811
# [125]	train's rmse: 1.61856	valid's rmse: 1.55394
# [150]	train's rmse: 1.58983	valid's rmse: 1.5369
# [175]	train's rmse: 1.56787	valid's rmse: 1.52676
# [200]	train's rmse: 1.55008	valid's rmse: 1.51909
# [225]	train's rmse: 1.53565	valid's rmse: 1.51414
# [250]	train's rmse: 1.52272	valid's rmse: 1.51063
# [275]	train's rmse: 1.51141	valid's rmse: 1.50859
# [300]	train's rmse: 1.50202	valid's rmse: 1.50675
# [325]	train's rmse: 1.49462	valid's rmse: 1.50618
# [350]	train's rmse: 1.488	valid's rmse: 1.50576
# [375]	train's rmse: 1.48189	valid's rmse: 1.50571
# [400]	train's rmse: 1.47673	valid's rmse: 1.50556
# [425]	train's rmse: 1.47248	valid's rmse: 1.50556
# [450]	train's rmse: 1.46923	valid's rmse: 1.50588
# [475]	train's rmse: 1.46659	valid's rmse: 1.50608
# [500]	train's rmse: 1.46478	valid's rmse: 1.50646
# Did not meet early stopping. Best iteration is:
# [500]	train's rmse: 1.46478	valid's rmse: 1.50646
# predict train set
# predict test set
# <feature_importance>
# 0 ('totals_pageviews_hit_rate', 8370)
# 1 ('totals_pageviews', 7151)
# 2 ('totals_hits', 4619)
# 3 ('visitNumber', 4614)
# 4 ('weekofyear', 4294)
# 5 ('geoNetwork_city', 4183)
# 6 ('geoNetwork_networkDomain', 3297)
# 7 ('source_country', 3015)
# 8 ('user_hour_mean', 2558)
# 9 ('user_hour_max', 1845)
# 10 ('browser_operatingSystem', 1777)
# 11 ('user_hour_min', 1691)
# 12 ('month_unique_user_count', 1670)
# 13 ('hour_unique_user_count', 1612)
# 14 ('day', 1580)
# 15 ('mean_hits_per_day', 1579)
# 16 ('month', 1493)
# 17 ('var_hits_per_day', 1440)
# 18 ('max_hits_per_day', 1351)
# 19 ('mean_hour_per_browser_operatingSystem', 1272)
# 20 ('day_unique_user_count', 1214)
# 21 ('max_hits_per_hour', 1206)
# 22 ('mean_pageviews_per_network_domain', 1153)
# 23 ('sum_hits_per_hour', 1115)
# 24 ('sum_pageviews_per_network_domain', 1075)
# 25 ('hour', 1064)
# 26 ('mean_hits_per_hour', 1039)
# 27 ('sum_hits_per_day', 998)
# 28 ('trafficSource_isTrueDirect', 960)
# 29 ('var_hits_per_hour', 898)
# 30 ('day_unique_s_count', 890)
# 31 ('geoNetwork_metro', 816)
# 32 ('weekday', 798)
# 33 ('weekday_unique_user_count', 743)
# 34 ('geoNetwork_region', 627)
# 35 ('geoNetwork_country', 618)
# 36 ('medium_hits_mean', 575)
# 37 ('mean_hits_per_network_domain', 560)
# 38 ('month_unique_s_count', 546)
# 39 ('trafficSource_source', 540)
# 40 ('totals_newVisits', 500)
# 41 ('count_pageviews_per_network_domain', 469)
# 42 ('hour_unique_s_count', 430)
# 43 ('browser_category', 352)
# 44 ('device_operatingSystem', 315)
# 45 ('medium_hits_sum', 302)
# 46 ('device_deviceCategory', 244)
# 47 ('totals_bounces', 145)
# 48 ('geoNetwork_subContinent', 143)
# 49 ('device_isMobile', 141)
# 50 ('sum_hits_per_network_domain', 139)
# 51 ('weekofmonth', 122)
# 52 ('channelGrouping', 110)
# 53 ('weekday_unique_s_count', 101)
# 54 ('trafficSource_keyword', 92)
# 55 ('campaign_medium', 64)
# 56 ('count_hits_per_network_domain', 51)
# 57 ('medium_hits_max', 29)
# 58 ('trafficSource_medium', 23)
# 59 ('geoNetwork_continent', 20)
# 60 ('device_browser', 18)
# 61 ('min_hits_per_day', 0)
# 62 ('min_hits_per_hour', 0)
# 63 ('medium_hits_min', 0)
# raw_train: results/2018-09-26T230543__T1.465_V1.506_K/reg_train_2018-09-26T230543.csv
# raw_test: results/2018-09-26T230543__T1.465_V1.506_K/reg_test_2018-09-26T230543.csv
# submit: results/2018-09-26T230543__T1.465_V1.506_K/aiden_2018-09-26T230543.csv.tar.gz
# cp -f reg_lgbm.ipynb results/2018-09-26T230543__T1.465_V1.506_K/reg_lgbm.ipynb
#
# results/2018-09-26T230543__T1.465_V1.506_K/aiden_2018-09-26T230543.csv.tar.gz
# Fold: GroupKFold_12
# Training until validation scores don't improve for 100 rounds.
# [25]	train's rmse: 1.8638	valid's rmse: 2.17504
# [50]	train's rmse: 1.7672	valid's rmse: 2.08022
# [75]	train's rmse: 1.69737	valid's rmse: 2.0166
# [100]	train's rmse: 1.64848	valid's rmse: 1.98086
# [125]	train's rmse: 1.61266	valid's rmse: 1.95962
# [150]	train's rmse: 1.58438	valid's rmse: 1.94625
# [175]	train's rmse: 1.5627	valid's rmse: 1.93679
# [200]	train's rmse: 1.54558	valid's rmse: 1.92968
# [225]	train's rmse: 1.53131	valid's rmse: 1.92551
# [250]	train's rmse: 1.51878	valid's rmse: 1.92257
# [275]	train's rmse: 1.50781	valid's rmse: 1.92056
# [300]	train's rmse: 1.49909	valid's rmse: 1.91835
# [325]	train's rmse: 1.49142	valid's rmse: 1.91549
# [350]	train's rmse: 1.48475	valid's rmse: 1.91567
# [375]	train's rmse: 1.47876	valid's rmse: 1.91513
# [400]	train's rmse: 1.47366	valid's rmse: 1.91511
# [425]	train's rmse: 1.4692	valid's rmse: 1.9151
# [450]	train's rmse: 1.46609	valid's rmse: 1.91473
# [475]	train's rmse: 1.46327	valid's rmse: 1.91463
# [500]	train's rmse: 1.46095	valid's rmse: 1.91364
# Did not meet early stopping. Best iteration is:
# [500]	train's rmse: 1.46095	valid's rmse: 1.91364
# predict train set
# predict test set
# <feature_importance>
# 0 ('totals_pageviews_hit_rate', 8703)
# 1 ('totals_pageviews', 7228)
# 2 ('totals_hits', 4758)
# 3 ('visitNumber', 4664)
# 4 ('weekofyear', 4346)
# 5 ('geoNetwork_city', 4318)
# 6 ('geoNetwork_networkDomain', 3524)
# 7 ('source_country', 2958)
# 8 ('user_hour_mean', 2492)
# 9 ('user_hour_max', 1839)
# 10 ('browser_operatingSystem', 1804)
# 11 ('user_hour_min', 1687)
# 12 ('hour_unique_user_count', 1603)
# 13 ('day', 1569)
# 14 ('month', 1553)
# 15 ('mean_hits_per_day', 1531)
# 16 ('month_unique_user_count', 1498)
# 17 ('var_hits_per_day', 1354)
# 18 ('day_unique_user_count', 1353)
# 19 ('mean_hour_per_browser_operatingSystem', 1306)
# 20 ('max_hits_per_day', 1297)
# 21 ('max_hits_per_hour', 1212)
# 22 ('mean_pageviews_per_network_domain', 1174)
# 23 ('mean_hits_per_hour', 1110)
# 24 ('hour', 1093)
# 25 ('sum_hits_per_hour', 1032)
# 26 ('sum_pageviews_per_network_domain', 1025)
# 27 ('trafficSource_isTrueDirect', 1001)
# 28 ('sum_hits_per_day', 969)
# 29 ('day_unique_s_count', 883)
# 30 ('geoNetwork_metro', 828)
# 31 ('weekday', 824)
# 32 ('var_hits_per_hour', 779)
# 33 ('weekday_unique_user_count', 714)
# 34 ('geoNetwork_country', 650)
# 35 ('geoNetwork_region', 646)
# 36 ('trafficSource_source', 627)
# 37 ('medium_hits_mean', 593)
# 38 ('mean_hits_per_network_domain', 534)
# 39 ('totals_newVisits', 531)
# 40 ('month_unique_s_count', 505)
# 41 ('count_pageviews_per_network_domain', 467)
# 42 ('hour_unique_s_count', 448)
# 43 ('browser_category', 350)
# 44 ('device_operatingSystem', 332)
# 45 ('medium_hits_sum', 305)
# 46 ('device_deviceCategory', 247)
# 47 ('totals_bounces', 157)
# 48 ('sum_hits_per_network_domain', 152)
# 49 ('channelGrouping', 147)
# 50 ('geoNetwork_subContinent', 135)
# 51 ('weekday_unique_s_count', 134)
# 52 ('device_isMobile', 129)
# 53 ('weekofmonth', 127)
# 54 ('trafficSource_keyword', 106)
# 55 ('campaign_medium', 59)
# 56 ('count_hits_per_network_domain', 41)
# 57 ('geoNetwork_continent', 22)
# 58 ('trafficSource_medium', 19)
# 59 ('medium_hits_max', 19)
# 60 ('device_browser', 13)
# 61 ('min_hits_per_day', 0)
# 62 ('min_hits_per_hour', 0)
# 63 ('medium_hits_min', 0)
# raw_train: results/2018-09-26T230704__T1.461_V1.914_K/reg_train_2018-09-26T230704.csv
# raw_test: results/2018-09-26T230704__T1.461_V1.914_K/reg_test_2018-09-26T230704.csv
# submit: results/2018-09-26T230704__T1.461_V1.914_K/aiden_2018-09-26T230704.csv.tar.gz
# cp -f reg_lgbm.ipynb results/2018-09-26T230704__T1.461_V1.914_K/reg_lgbm.ipynb
#
# results/2018-09-26T230704__T1.461_V1.914_K/aiden_2018-09-26T230704.csv.tar.gz

# %% [markdown]
# ### Submit

# %%
df_train_idx['y_true'] = df_train_y.values
df_train_idx['y_pred_sum'] = prediction_train
df_train_idx['y_pred_avg'] = prediction_train / 13
df_train_idx['y_diff'] = df_train_idx['y_true'] - df_train_idx['y_pred_avg']
# Out:
# /Users/hyundai/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/hyundai/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/hyundai/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_train_idx[df_train_idx['y_true'] > 0]
# Out:
#               fullVisitorId  totals_transactionRevenue      y_pred  \
# 752     6194193421514403509                 37860000.0   76.324816
# 753     5327166854580374902                306670000.0   85.517484
# 799     8885051388942907862                 68030000.0  174.511709
# 802     0185467632009737931                 26250000.0   68.420434
# 859     3244885836845029978                574150000.0  168.051073
# 866     3351538799616866750                  8380000.0   55.299643
# 893     1776658355119092313                395730000.0   47.535508
# 910      770431600902969839                 24080000.0  134.129131
# 922     7147112211830167925                 35480000.0   35.014300
# 925     6664733704830724714                 35080000.0  106.130502
# 930     6045930241388777741                 81500000.0   77.370064
# 942     1546626226233851002                546320000.0  148.308760
# 971     4755168908070236728                 63840000.0  200.368844
# 974     3794016165791476291                117340000.0   41.196745
# 976     0314733033105141755                 43710000.0   86.535644
# 999      747690048733385763                 34480000.0  120.108403
# 1000    8007300615127214527                 35390000.0  221.968130
# 1008    8516473451212465925                339030000.0  220.283383
# 1020    6712520540378436905                 33670000.0  114.278585
# 1022    3152246617474456269                635500000.0  264.536143
# 1026    1881458907401964229                103240000.0   40.328766
# 1027    1095886019324498043                305470000.0  208.119669
# 1037    8585031285178547027                  5150000.0  138.133312
# 1041    3741689406060673010                 90850000.0  150.544527
# 1054    4293841073200012958                 10590000.0  303.808577
# 1055    0643132668463442280                 25680000.0   50.530973
# 1056    1710046532262949205                338970000.0  221.406084
# 2774    7168226225550508027                593910000.0  282.235595
# 3161    2923583380085498492                 44790000.0   11.240668
# 3268      62722204677243801                 30390000.0   95.657332
# ...                     ...                        ...         ...
# 899951  7451284399359627657                 43430000.0  125.349373
# 903089   992812962494074450                 44790000.0   95.505951
# 903118  2272979836636092591                175800000.0   77.146271
# 903122  4123860234327657457                 87990000.0  169.452999
# 903167  0159084910202112487                 14370000.0   19.320097
# 903168  9710480501909231921                155970000.0  182.556639
# 903189  3554960621245001989                 75180000.0  198.443528
# 903194  3826933837621771483                350000000.0  197.911896
# 903201  2591017631506070831                135920000.0   25.798991
# 903211  9670996124580137796                159980000.0  240.007070
# 903222  6726478899201625475                 23180000.0  185.125479
# 903228  3301001176863952275                 22970000.0   90.263697
# 903234  7199611745811583535                463600000.0  292.643391
# 903235  4967676136502125585                 79990000.0  216.056725
# 903243  7742753003683875687                 76780000.0  254.282818
# 903249  8406359927975063956                 12990000.0  133.146125
# 903256  9961713390620821018                 34970000.0  102.098355
# 903259  3347706947631375795                 91080000.0  276.516262
# 903262  6908387488019906910                 46110000.0  329.802874
# 903271  3243512505311500350                 85980000.0  103.047277
# 903275  0839560865423027275                 55160000.0  222.918839
# 903284  4301598633370091052                 51890000.0  165.660972
# 903285  0081840705529000272                119960000.0  326.134742
# 903291  2411322974724385937                 19190000.0  319.131426
# 903298  5414778440969335716                111980000.0  302.836929
# 903302  6849604863010168468                335260000.0  337.572277
# 903305  0211986650009953276                599950000.0  188.527340
# 903314  9981562221973608723                 30750000.0  163.529492
# 903315   963126344221316701                 69390000.0  223.403227
# 903317  9771437221362506189                 74990000.0  218.701781
#
#         y_pred_sum  y_pred_avg     y_true
# 752      76.324816    5.871140  17.449406
# 753      85.517484    6.578268  19.541283
# 799     174.511709   13.423978  18.035459
# 802      68.420434    5.263110  17.083177
# 859     168.051073   12.927006  20.168401
# 866      55.299643    4.253819  15.941359
# 893      47.535508    3.656578  19.796243
# 910     134.129131   10.317625  16.996892
# 922      35.014300    2.693408  17.384480
# 925     106.130502    8.163885  17.373142
# 930      77.370064    5.951543  18.216114
# 942     148.308760   11.408366  20.118715
# 971     200.368844   15.412988  17.971891
# 974      41.196745    3.168980  18.580586
# 976      86.535644    6.656588  17.593087
# 999     120.108403    9.239108  17.355890
# 1000    221.968130   17.074472  17.381940
# 1008    220.283383   16.944876  19.641599
# 1020    114.278585    8.790660  17.332118
# 1022    264.536143   20.348934  20.269923
# 1026     40.328766    3.102213  18.452567
# 1027    208.119669   16.009205  19.537362
# 1037    138.133312   10.625639  15.454507
# 1041    150.544527   11.580348  18.324720
# 1054    303.808577   23.369891  16.175421
# 1055     50.530973    3.886998  17.061223
# 1056    221.406084   17.031237  19.641422
# 2774    282.235595   21.710430  20.202238
# 3161     11.240668    0.864667  17.617495
# 3268     95.657332    7.358256  17.229624
# ...            ...         ...        ...
# 899951  125.349373    9.642259  17.586661
# 903089   95.505951    7.346612  17.617495
# 903118   77.146271    5.934329  18.984858
# 903122  169.452999   13.034846  18.292734
# 903167   19.320097    1.486161  16.480653
# 903168  182.556639   14.042818  18.865174
# 903189  198.443528   15.264887  18.135396
# 903194  197.911896   15.223992  19.673444
# 903201   25.798991    1.984538  18.727577
# 903211  240.007070   18.462082  18.890559
# 903222  185.125479   14.240421  16.958800
# 903228   90.263697    6.943361  16.949700
# 903234  292.643391   22.511030  19.954533
# 903235  216.056725   16.619748  18.197412
# 903243  254.282818   19.560217  18.156455
# 903249  133.146125   10.242010  16.379690
# 903256  102.098355    7.853720  17.370001
# 903259  276.516262   21.270482  18.327249
# 903262  329.802874   25.369452  17.646540
# 903271  103.047277    7.926714  18.269625
# 903275  222.918839   17.147603  17.825749
# 903284  165.660972   12.743152  17.764637
# 903285  326.134742   25.087288  18.602669
# 903291  319.131426   24.548571  16.769900
# 903298  302.836929   23.295148  18.533831
# 903302  337.572277   25.967098  19.630417
# 903305  188.527340   14.502103  20.212357
# 903314  163.529492   12.579192  17.241401
# 903315  223.403227   17.184864  18.055253
# 903317  218.701781   16.823214  18.132865
#
# [11515 rows x 6 columns]

# %%
df_train_X[df_train['fullVisitorId']=='8007300615127214527']
# Out:
#         channelGrouping  visitNumber  device_browser  device_deviceCategory  \
# 1000                  0     1.386294               0                      0
# 62193                 0     0.693147               0                      0
# 188632                0     1.098612               0                      0
# 407085                0     1.609438               0                      0
#
#         device_isMobile  device_operatingSystem  geoNetwork_city  \
# 1000                  0                       1               47
# 62193                 0                       1               47
# 188632                0                       1               47
# 407085                0                       1               47
#
#         geoNetwork_continent  geoNetwork_country  geoNetwork_metro  \
# 1000                       3                  33                 3
# 62193                      3                  33                 3
# 188632                     3                  33                 3
# 407085                     3                  33                 3
#
#              ...         count_pageviews_per_network_domain  \
# 1000         ...                                     244881
# 62193        ...                                     244881
# 188632       ...                                     244881
# 407085       ...                                     244881
#
#         mean_pageviews_per_network_domain  sum_hits_per_network_domain  \
# 1000                             1.413671                362835.303771
# 62193                            1.413671                362835.303771
# 188632                           1.413671                362835.303771
# 407085                           1.413671                362835.303771
#
#         count_hits_per_network_domain  mean_hits_per_network_domain  \
# 1000                           244881                       1.48168
# 62193                          244881                       1.48168
# 188632                         244881                       1.48168
# 407085                         244881                       1.48168
#
#         campaign_medium  medium_hits_mean  medium_hits_max  medium_hits_min  \
# 1000                  0          1.318723         6.216606         0.693147
# 62193                 0          1.318723         6.216606         0.693147
# 188632                0          1.318723         6.216606         0.693147
# 407085                0          1.318723         6.216606         0.693147
#
#         medium_hits_sum
# 1000      503173.377428
# 62193     503173.377428
# 188632    503173.377428
# 407085    503173.377428
#
# [4 rows x 64 columns]

# %%
from sklearn.metrics import mean_squared_error

df_g = df_train_idx.groupby('fullVisitorId').agg({'y_true':'sum', 'y_pred_avg':'sum'})

# %%
mse = mean_squared_error(df_g['y_true'], df_g['y_pred_avg'])
np.sqrt(mse)
# Out:
# 2.315754261394708

# %% [markdown]
# ### to Kaggle with MSG

# %%
# cmd = """kaggle competitions submit -c ga-customer-revenue-prediction -f {file_path} -m "{msg}"
# """.format(**{'file_path': submit_file_path, 'msg': ','.join(msg)[:500]})

cmd = """kaggle competitions submit -c ga-customer-revenue-prediction -f {file_path} -m "{msg}"
""".format(**{'file_path': submit_file_path, 'msg': 'msg'})

print(cmd)
subprocess.call(cmd, shell=True)
